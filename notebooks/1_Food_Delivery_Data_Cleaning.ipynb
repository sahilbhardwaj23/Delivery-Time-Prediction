# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Load Data

# %%
# load the csv file

df = pd.read_csv("swiggy.csv")

df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
# 1                    77.813237  25-03-2022    19:45:00          19:50:00
# 2                    77.688400  19-03-2022    08:30:00          08:45:00
# 3                    77.026494  05-04-2022    18:00:00          18:10:00
# 4                    80.289982  26-03-2022    13:30:00          13:45:00
#
#        Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0       conditions Sunny                High                   2
# 1      conditions Stormy                 Jam                   2
# 2  conditions Sandstorms                 Low                   0
# 3       conditions Sunny              Medium                   0
# 4      conditions Cloudy                High                   1
#
#   Type_of_order Type_of_vehicle multiple_deliveries Festival            City  \
# 0        Snack      motorcycle                    0      No           Urban
# 1        Snack         scooter                    1      No   Metropolitian
# 2       Drinks      motorcycle                    1      No           Urban
# 3       Buffet      motorcycle                    1      No   Metropolitian
# 4        Snack         scooter                    1      No   Metropolitian
#
#   Time_taken(min)
# 0        (min) 24
# 1        (min) 33
# 2        (min) 26
# 3        (min) 21
# 4        (min) 30

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)'],
#       dtype='object')

# %%
# shape of data

rows, cols = df.shape

print("The dataset has {} rows and {} columns".format(rows,cols))
# Out:
# The dataset has 45593 rows and 20 columns

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %%
# info about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
#  12  Road_traffic_density         45593 non-null  object
#  13  Vehicle_condition            45593 non-null  int64
#  14  Type_of_order                45593 non-null  object
#  15  Type_of_vehicle              45593 non-null  object
#  16  multiple_deliveries          45593 non-null  object
#  17  Festival                     45593 non-null  object
#  18  City                         45593 non-null  object
#  19  Time_taken(min)              45593 non-null  object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 7.0+ MB

# %% [markdown]
# **Corrections**:
#
# 1. Age column should be numerical.
# 2. Ratings should be float.
# 3. Date and time columns should be date and time.
# 4. Vehicle conditions seems to be categorical column which is integer encoded.
# 5. Multiple deliveries should be integer column.
# 6. Target column should also be numbers.

# %%
# missing values in data

df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# **There are no missing values in the data**

# %%
# sample 50 rows of data for viewing

df.sample(50)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 34211  0x7ca4     CHENRES07DEL02                   35                     4.9
# 28666  0xb8d2      MUMRES07DEL02                   26                     4.6
# 5947   0x30fa      JAPRES14DEL01                   22                     4.8
# 17069  0x71d0   RANCHIRES16DEL01                   38                     4.5
# 20590  0x7b0a      MUMRES13DEL03                   23                     4.8
# 12917  0xa019   RANCHIRES06DEL03                   24                     4.6
# 10323  0x7fab      MYSRES01DEL02                   22                     4.9
# 29872  0x8b22      VADRES02DEL02                   36                     4.6
# 39090  0xadc4     BANGRES02DEL01                   39                     4.1
# 19385  0x6099    COIMBRES07DEL01                   27                     4.1
# 39354  0xded4      KOLRES17DEL01                   21                     4.2
# 13359  0xca6c     AURGRES14DEL02                   21                       5
# 17194  0xb9eb      MYSRES12DEL02                   38                     4.8
# 24798  0x4447    COIMBRES14DEL02                   26                     4.5
# 15797  0x31b8    COIMBRES08DEL02                   23                     4.8
# 35816  0x50c3      VADRES01DEL01                   32                     4.8
# 41647  0x1bce      HYDRES18DEL01                   23                     4.8
# 15948  0x959b      JAPRES08DEL03                   34                     4.2
# 11340  0xcceb      KOCRES02DEL01                   26                     4.7
# 551    0xa8b9      VADRES12DEL02                   20                     4.9
# 27420  0xd8ca      KOCRES04DEL01                   24                       5
# 29566  0x9429     CHENRES05DEL03                   20                     4.7
# 15462  0xa676      JAPRES15DEL01                   33                     3.5
# 23047  0xcabc      BHPRES02DEL03                   34                     4.1
# 32122  0x4f02    COIMBRES17DEL02                   38                     3.7
# 20956  0x37a6    COIMBRES17DEL03                   21                     4.6
# 380    0xc595      DEHRES19DEL01                   29                     4.6
# 1838   0xccb8      DEHRES04DEL01                   38                     4.8
# 16644  0xae60    COIMBRES01DEL01                   22                       5
# 29385  0xa381      MYSRES12DEL02                   26                     4.5
# 22934  0x2bbc      HYDRES07DEL02                   27                       5
# 42097   0x61e      MYSRES03DEL02                 NaN                     NaN
# 933    0xb619     INDORES13DEL01                   35                     4.8
# 6819   0x4c4a     CHENRES14DEL03                   29                     4.9
# 2870   0x4586     CHENRES14DEL02                   33                     4.3
# 8754   0x7e6b     CHENRES15DEL01                   33                     4.9
# 4520   0x1b97    COIMBRES02DEL03                   22                     4.8
# 1331   0x8c95      VADRES12DEL01                   27                     4.9
# 41619   0x94f      HYDRES09DEL03                 NaN                     NaN
# 3151   0xc092      KNPRES11DEL01                   39                       5
# 31311  0x49d2      SURRES02DEL02                   20                     4.6
# 16523  0xd81c      ALHRES19DEL01                   30                     4.8
# 39771   0x9c5    COIMBRES04DEL03                   26                     4.9
# 30782  0x661e      MYSRES09DEL03                   33                     3.6
# 29998  0x1212   RANCHIRES06DEL01                   38                     3.7
# 15536  0x9c0b   RANCHIRES02DEL01                   30                     4.5
# 37850  0x2907     BANGRES18DEL01                   23                     4.9
# 41623  0x8fc6      MUMRES15DEL03                   27                     4.6
# 7566   0x36ec      MUMRES17DEL01                   26                     4.7
# 18316  0xd40a     KOCRES010DEL02                   39                     4.5
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 34211            13.081878             80.248519                   13.101878
# 28666            19.091458             72.827808                   19.141458
# 5947             26.888420             75.800689                   26.998420
# 17069            23.371292             85.327872                   23.441292
# 20590            19.178321             72.834715                   19.208321
# 12917            23.357804             85.325146                   23.447804
# 10323            12.311072             76.654878                   12.361072
# 29872             0.000000              0.000000                    0.080000
# 39090            12.970221             77.645396                   12.980221
# 19385            10.961850             76.971082                   10.971850
# 39354            22.569358             88.433452                   22.679358
# 13359            19.875016             75.322405                   19.955016
# 17194            12.284747             76.625861                   12.334747
# 24798            11.003681             76.975525                   11.023681
# 15797            11.001852             76.976268                   11.051852
# 35816            22.307898             73.167788                   22.317898
# 41647            17.450851             78.379347                   17.520851
# 15948            26.910262             75.783013                   27.000262
# 11340            10.028047             76.310019                   10.138047
# 551               0.000000              0.000000                    0.020000
# 27420             9.966783             76.242981                   10.076783
# 29566            13.058616             80.264151                   13.148616
# 15462            26.891191             75.802083                   26.961191
# 23047             0.000000              0.000000                    0.030000
# 32122            11.026117             76.944652                   11.156117
# 20956            11.026117             76.944652                   11.116117
# 380              30.372202             78.077151                   30.442202
# 1838             30.340722             78.060221                   30.450722
# 16644            11.016298             76.972076                   11.056298
# 29385            12.284747             76.625861                   12.304747
# 22934            17.424114             78.347554                   17.554114
# 42097            12.299524             76.642620                   12.379524
# 933              22.745049             75.892471                   22.815049
# 6819             13.026279             80.174568                   13.116279
# 2870             13.026279             80.174568                   13.076279
# 8754             13.026286             80.275235                   13.096286
# 4520             11.022477             76.995667                   11.112477
# 1331              0.000000              0.000000                    0.110000
# 41619            17.431668             78.408321                   17.461668
# 3151            -26.474986             80.342796                   26.584986
# 31311            21.186608             72.794136                   21.266608
# 16523            25.457116             81.859682                   25.567116
# 39771            11.024839             77.007003                   11.054839
# 30782            12.323194             76.630583                   12.413194
# 29998            23.357804             85.325146                   23.467804
# 15536             0.000000              0.000000                    0.010000
# 37850            12.913041             77.683237                   13.023041
# 41623            19.176269             72.836721                   19.206269
# 7566             19.121999             72.908493                   19.231999
# 18316            10.035573             76.336958                   10.115573
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 34211                    80.268519  05-04-2022    11:45:00          11:50:00
# 28666                    72.877808  15-03-2022    17:15:00          17:25:00
# 5947                     75.910689  10-03-2022    18:25:00          18:35:00
# 17069                    85.397872  08-03-2022    18:10:00          18:25:00
# 20590                    72.864715  17-03-2022    23:15:00          23:25:00
# 12917                    85.415146  10-03-2022    19:55:00          20:10:00
# 10323                    76.704878  07-03-2022    22:50:00          23:05:00
# 29872                     0.080000  29-03-2022    19:35:00          19:50:00
# 39090                    77.655396  09-03-2022    10:10:00          10:20:00
# 19385                    76.981082  03-03-2022    08:15:00          08:25:00
# 39354                    88.543452  14-02-2022    21:55:00          22:00:00
# 13359                    75.402405  12-02-2022    23:45:00          23:55:00
# 17194                    76.675861  01-04-2022    20:30:00          20:35:00
# 24798                    76.995525  01-03-2022    11:20:00          11:25:00
# 15797                    77.026268  24-03-2022    18:55:00          19:10:00
# 35816                    73.177788  28-03-2022    10:25:00          10:35:00
# 41647                    78.449347  23-03-2022    19:10:00          19:20:00
# 15948                    75.873013  06-04-2022    19:00:00          19:05:00
# 11340                    76.420019  14-02-2022    23:20:00          23:25:00
# 551                       0.020000  03-04-2022    08:10:00          08:20:00
# 27420                    76.352981  12-02-2022    20:25:00          20:40:00
# 29566                    80.354151  02-03-2022    18:20:00          18:30:00
# 15462                    75.872083  14-03-2022    22:50:00          23:00:00
# 23047                     0.030000  13-02-2022    19:25:00          19:40:00
# 32122                    77.074652  25-03-2022    17:50:00          18:00:00
# 20956                    77.034652  06-03-2022    23:00:00          23:10:00
# 380                      78.147151  18-02-2022    23:40:00          23:55:00
# 1838                     78.170221  14-02-2022    20:35:00          20:50:00
# 16644                    77.012076  26-03-2022    16:15:00          16:20:00
# 29385                    76.645861  21-03-2022    09:10:00          09:15:00
# 22934                    78.477554  04-03-2022    17:45:00          18:00:00
# 42097                    76.722620  14-03-2022        NaN           18:30:00
# 933                      75.962471  06-03-2022    23:00:00          23:15:00
# 6819                     80.264568  02-03-2022    21:35:00          21:50:00
# 2870                     80.224568  05-03-2022    19:20:00          19:35:00
# 8754                     80.345235  02-03-2022    20:55:00          21:10:00
# 4520                     77.085667  04-03-2022    17:35:00          17:50:00
# 1331                      0.110000  27-03-2022    19:15:00          19:25:00
# 41619                    78.438321  03-03-2022        NaN           18:25:00
# 3151                     80.452796  12-02-2022    23:40:00          23:50:00
# 31311                    72.874136  04-03-2022    17:45:00          17:50:00
# 16523                    81.969682  14-02-2022    17:30:00          17:35:00
# 39771                    77.037003  17-03-2022    23:15:00          23:20:00
# 30782                    76.720583  23-03-2022    18:30:00          18:40:00
# 29998                    85.435146  27-03-2022    22:30:00          22:45:00
# 15536                     0.010000  05-04-2022    10:35:00          10:40:00
# 37850                    77.793237  25-03-2022    23:25:00          23:35:00
# 41623                    72.866721  19-03-2022    19:00:00          19:05:00
# 7566                     73.018493  16-03-2022    20:10:00          20:15:00
# 18316                    76.416958  12-02-2022    19:10:00          19:20:00
#
#            Weatherconditions Road_traffic_density  Vehicle_condition  \
# 34211      conditions Cloudy                High                   2
# 28666       conditions Windy              Medium                   1
# 5947        conditions Sunny              Medium                   1
# 17069       conditions Sunny              Medium                   1
# 20590         conditions Fog                 Low                   1
# 12917       conditions Windy                 Jam                   1
# 10323       conditions Sunny                 Low                   2
# 29872  conditions Sandstorms                 Jam                   1
# 39090      conditions Stormy                 Low                   0
# 19385       conditions Windy                 Low                   0
# 39354  conditions Sandstorms                 Jam                   0
# 13359      conditions Cloudy                 Low                   0
# 17194         conditions Fog                 Jam                   1
# 24798      conditions Stormy                High                   2
# 15797       conditions Windy              Medium                   0
# 35816  conditions Sandstorms                 Low                   1
# 41647         conditions Fog                 Jam                   2
# 15948  conditions Sandstorms              Medium                   0
# 11340      conditions Cloudy                 Low                   0
# 551        conditions Stormy                 Low                   1
# 27420  conditions Sandstorms                 Jam                   1
# 29566  conditions Sandstorms              Medium                   1
# 15462         conditions Fog                 Low                   2
# 23047  conditions Sandstorms                 Jam                   2
# 32122       conditions Windy              Medium                   2
# 20956         conditions Fog                 Low                   1
# 380    conditions Sandstorms                 Low                   0
# 1838        conditions Sunny                 Jam                   0
# 16644       conditions Sunny              Medium                   0
# 29385         conditions Fog                 Low                   2
# 22934         conditions Fog              Medium                   1
# 42097      conditions Cloudy              Medium                   1
# 933         conditions Sunny                 Low                   2
# 6819          conditions Fog                 Jam                   0
# 2870          conditions Fog                 Jam                   2
# 8754       conditions Cloudy                 Jam                   2
# 4520        conditions Sunny              Medium                   1
# 1331   conditions Sandstorms                 Jam                   2
# 41619       conditions Sunny              Medium                   2
# 3151       conditions Stormy                 Low                   0
# 31311       conditions Windy              Medium                   0
# 16523      conditions Cloudy              Medium                   2
# 39771  conditions Sandstorms                 Low                   1
# 30782       conditions Windy              Medium                   2
# 29998         conditions Fog                 Low                   1
# 15536  conditions Sandstorms                 Low                   0
# 37850       conditions Windy                 Low                   0
# 41623       conditions Sunny              Medium                   0
# 7566        conditions Sunny                 Jam                   0
# 18316       conditions Windy                 Jam                   1
#
#       Type_of_order    Type_of_vehicle multiple_deliveries Festival  \
# 34211        Snack            scooter                    1      No
# 28666       Drinks            scooter                    0      No
# 5947        Drinks         motorcycle                    1      No
# 17069       Drinks         motorcycle                    1      No
# 20590        Snack         motorcycle                    1      No
# 12917       Drinks            scooter                    1      No
# 10323       Drinks         motorcycle                    1      No
# 29872       Drinks         motorcycle                    1      No
# 39090        Snack         motorcycle                    1      No
# 19385        Snack         motorcycle                    0      No
# 39354       Drinks         motorcycle                    1      No
# 13359       Drinks         motorcycle                    1      No
# 17194       Drinks            scooter                    0      No
# 24798        Snack         motorcycle                    1      No
# 15797       Buffet         motorcycle                    0      No
# 35816         Meal         motorcycle                    1      No
# 41647       Buffet            scooter                    1      No
# 15948       Buffet         motorcycle                    1      No
# 11340        Snack         motorcycle                    0      No
# 551           Meal         motorcycle                    1      No
# 27420         Meal            scooter                    1      No
# 29566        Snack         motorcycle                    1      No
# 15462         Meal         motorcycle                    0      No
# 23047       Drinks            scooter                    1      No
# 32122        Snack            scooter                    1      No
# 20956         Meal            scooter                    0      No
# 380           Meal         motorcycle                    0      No
# 1838        Buffet         motorcycle                    1      No
# 16644         Meal         motorcycle                    0      No
# 29385       Drinks            scooter                    0      No
# 22934         Meal            scooter                    1      No
# 42097        Snack         motorcycle                    1      No
# 933          Snack            scooter                    1      No
# 6819         Snack         motorcycle                    0      No
# 2870         Snack   electric_scooter                    0      No
# 8754        Drinks            scooter                    2      No
# 4520         Snack         motorcycle                    1      No
# 1331        Drinks            scooter                    1      No
# 41619         Meal         motorcycle                    1      No
# 3151        Drinks         motorcycle                    1      No
# 31311         Meal         motorcycle                    1      No
# 16523        Snack            scooter                    2      No
# 39771        Snack            scooter                    0      No
# 30782       Drinks   electric_scooter                    0      No
# 29998       Drinks         motorcycle                    1      No
# 15536       Buffet         motorcycle                    0      No
# 37850       Buffet         motorcycle                    1      No
# 41623       Buffet         motorcycle                    1      No
# 7566          Meal         motorcycle                    0      No
# 18316       Buffet         motorcycle                    1      No
#
#                  City Time_taken(min)
# 34211  Metropolitian         (min) 25
# 28666          Urban         (min) 21
# 5947   Metropolitian         (min) 19
# 17069  Metropolitian         (min) 29
# 20590  Metropolitian         (min) 17
# 12917  Metropolitian         (min) 28
# 10323  Metropolitian         (min) 23
# 29872  Metropolitian         (min) 29
# 39090  Metropolitian         (min) 22
# 19385          Urban         (min) 16
# 39354  Metropolitian         (min) 36
# 13359  Metropolitian         (min) 20
# 17194  Metropolitian         (min) 36
# 24798  Metropolitian         (min) 12
# 15797  Metropolitian         (min) 10
# 35816  Metropolitian         (min) 21
# 41647  Metropolitian         (min) 44
# 15948  Metropolitian         (min) 40
# 11340          Urban         (min) 21
# 551            Urban         (min) 11
# 27420  Metropolitian         (min) 28
# 29566  Metropolitian         (min) 20
# 15462  Metropolitian         (min) 36
# 23047  Metropolitian         (min) 32
# 32122  Metropolitian         (min) 36
# 20956  Metropolitian         (min) 27
# 380    Metropolitian         (min) 22
# 1838   Metropolitian         (min) 35
# 16644  Metropolitian         (min) 21
# 29385  Metropolitian         (min) 11
# 22934  Metropolitian         (min) 35
# 42097  Metropolitian         (min) 26
# 933            Urban         (min) 20
# 6819   Metropolitian         (min) 35
# 2870   Metropolitian         (min) 37
# 8754           Urban         (min) 41
# 4520           Urban         (min) 10
# 1331   Metropolitian         (min) 22
# 41619          Urban         (min) 17
# 3151   Metropolitian         (min) 25
# 31311  Metropolitian         (min) 27
# 16523  Metropolitian         (min) 38
# 39771  Metropolitian         (min) 18
# 30782  Metropolitian         (min) 35
# 29998  Metropolitian         (min) 39
# 15536  Metropolitian         (min) 28
# 37850          Urban         (min) 17
# 41623            NaN         (min) 16
# 7566           Urban         (min) 17
# 18316  Metropolitian         (min) 32

# %% [markdown]
# Some values are filled with 'NaN' as an entry which means in reality they are null values

# %% [markdown]
# # Missing values
#
# Missing values are string type in the data with an extra space.

# %%
df.loc[43317,"Delivery_person_Ratings"]
# Out:
# 'NaN '

# %%
# String NaNs in the data

(df == "NaN ").sum().sum()
# Out:
# 8515

# %% [markdown]
# 8515 such NaN's in the data

# %%
# column wise string NaNs

(df == "NaN ").sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
# replace string NaN with NaN

df.replace("NaN ",np.NaN)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:30:00          11:45:00
# 1                        77.813237  25-03-2022    19:45:00          19:50:00
# 2                        77.688400  19-03-2022    08:30:00          08:45:00
# 3                        77.026494  05-04-2022    18:00:00          18:10:00
# 4                        80.289982  26-03-2022    13:30:00          13:45:00
# ...                            ...         ...         ...               ...
# 45588                    75.804257  24-03-2022    11:35:00          11:45:00
# 45589                     0.070000  16-02-2022    19:55:00          20:10:00
# 45590                    80.272439  11-03-2022    23:50:00          00:05:00
# 45591                    77.026241  07-03-2022    13:35:00          13:40:00
# 45592                    85.405731  02-03-2022    17:10:00          17:15:00
#
#            Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0           conditions Sunny                High                   2
# 1          conditions Stormy                 Jam                   2
# 2      conditions Sandstorms                 Low                   0
# 3           conditions Sunny              Medium                   0
# 4          conditions Cloudy                High                   1
# ...                      ...                  ...                ...
# 45588       conditions Windy                High                   1
# 45589       conditions Windy                 Jam                   0
# 45590      conditions Cloudy                 Low                   1
# 45591      conditions Cloudy                High                   0
# 45592         conditions Fog              Medium                   2
#
#       Type_of_order Type_of_vehicle multiple_deliveries Festival  \
# 0            Snack      motorcycle                    0      No
# 1            Snack         scooter                    1      No
# 2           Drinks      motorcycle                    1      No
# 3           Buffet      motorcycle                    1      No
# 4            Snack         scooter                    1      No
# ...             ...             ...                 ...      ...
# 45588         Meal      motorcycle                    0      No
# 45589       Buffet      motorcycle                    1      No
# 45590       Drinks         scooter                    0      No
# 45591        Snack      motorcycle                    1      No
# 45592        Snack         scooter                    1      No
#
#                  City Time_taken(min)
# 0              Urban         (min) 24
# 1      Metropolitian         (min) 33
# 2              Urban         (min) 26
# 3      Metropolitian         (min) 21
# 4      Metropolitian         (min) 30
# ...               ...             ...
# 45588  Metropolitian         (min) 32
# 45589  Metropolitian         (min) 36
# 45590  Metropolitian         (min) 16
# 45591  Metropolitian         (min) 26
# 45592  Metropolitian         (min) 36
#
# [45593 rows x 20 columns]

# %%
# verify missing values in the data

df.replace("NaN ",np.NaN).isna().sum().sum()
# Out:
# 8515

# %% [markdown]
# **Verified that string NaNs converted to Nan**

# %%
df['Weatherconditions'].sample(10)
# Out:
# 6382          conditions Sunny
# 15490         conditions Sunny
# 35321           conditions Fog
# 31362    conditions Sandstorms
# 28183           conditions Fog
# 14791         conditions Windy
# 42387           conditions Fog
# 43195         conditions Sunny
# 6877            conditions Fog
# 36136        conditions Cloudy
# Name: Weatherconditions, dtype: object

# %%
# NaN in the weather column
(
    df.loc[:,"Weatherconditions"]
    .str.replace("conditions ","")
    .replace("NaN",np.NaN)
    .isna().sum()
)
# Out:
# 616

# %%
df['Weatherconditions'].value_counts()
# Out:
# Weatherconditions
# conditions Fog           7654
# conditions Stormy        7586
# conditions Cloudy        7536
# conditions Sandstorms    7495
# conditions Windy         7422
# conditions Sunny         7284
# conditions NaN            616
# Name: count, dtype: int64

# %% [markdown]
# **616 missing values in the weather column**

# %% [markdown]
# we will create a another dataframe that contains the missing values

# %%
# df with all the missing values replace

missing_df = (
    df.replace("NaN ",np.NaN)
    .assign(
        Weatherconditions = lambda df_ : (
            df_['Weatherconditions']
            .str.replace("conditions ","")
            .replace("NaN",np.NaN)
            )
    )
)

missing_df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:30:00          11:45:00
# 1                        77.813237  25-03-2022    19:45:00          19:50:00
# 2                        77.688400  19-03-2022    08:30:00          08:45:00
# 3                        77.026494  05-04-2022    18:00:00          18:10:00
# 4                        80.289982  26-03-2022    13:30:00          13:45:00
# ...                            ...         ...         ...               ...
# 45588                    75.804257  24-03-2022    11:35:00          11:45:00
# 45589                     0.070000  16-02-2022    19:55:00          20:10:00
# 45590                    80.272439  11-03-2022    23:50:00          00:05:00
# 45591                    77.026241  07-03-2022    13:35:00          13:40:00
# 45592                    85.405731  02-03-2022    17:10:00          17:15:00
#
#       Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                 Sunny                High                   2        Snack
# 1                Stormy                 Jam                   2        Snack
# 2            Sandstorms                 Low                   0       Drinks
# 3                 Sunny              Medium                   0       Buffet
# 4                Cloudy                High                   1        Snack
# ...                 ...                  ...                ...           ...
# 45588             Windy                High                   1         Meal
# 45589             Windy                 Jam                   0       Buffet
# 45590            Cloudy                 Low                   1       Drinks
# 45591            Cloudy                High                   0        Snack
# 45592               Fog              Medium                   2        Snack
#
#       Type_of_vehicle multiple_deliveries Festival            City  \
# 0         motorcycle                    0      No           Urban
# 1            scooter                    1      No   Metropolitian
# 2         motorcycle                    1      No           Urban
# 3         motorcycle                    1      No   Metropolitian
# 4            scooter                    1      No   Metropolitian
# ...               ...                 ...      ...             ...
# 45588     motorcycle                    0      No   Metropolitian
# 45589     motorcycle                    1      No   Metropolitian
# 45590        scooter                    0      No   Metropolitian
# 45591     motorcycle                    1      No   Metropolitian
# 45592        scooter                    1      No   Metropolitian
#
#       Time_taken(min)
# 0            (min) 24
# 1            (min) 33
# 2            (min) 26
# 3            (min) 21
# 4            (min) 30
# ...               ...
# 45588        (min) 32
# 45589        (min) 36
# 45590        (min) 16
# 45591        (min) 26
# 45592        (min) 36
#
# [45593 rows x 20 columns]

# %%
# missing values in data

missing_df.isna().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
# total missing values in data

missing_df.isna().sum().sum()
# Out:
# 9131

# %% [markdown]
# ## Missing Value Analysis

# %% [markdown]
# ### Matrix

# %%
# missing values matrix

msno.matrix(missing_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Count of Missing Values

# %%
# bar plot for columns having missing data

msno.bar(missing_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Missing Corr

# %%
missing_df[["Weatherconditions","Road_traffic_density"]].isna().sum()
# Out:
# Weatherconditions       616
# Road_traffic_density    601
# dtype: int64

# %%
# prove point of missingness

(
    missing_df[["Weatherconditions","Road_traffic_density"]]
    .isna().all(axis=1)
    .sum()
) /  missing_df[["Weatherconditions","Road_traffic_density"]].isna().sum()
# Out:
# Weatherconditions       0.975649
# Road_traffic_density    1.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)'],
#       dtype='object')

# %%
# prove point of missingness

(
    missing_df[["Delivery_person_Age","Delivery_person_Ratings"]]
    .isna().all(axis=1)
    .sum()
) /  missing_df[["Delivery_person_Age","Delivery_person_Ratings"]].isna().sum()
# Out:
# Delivery_person_Age        1.000000
# Delivery_person_Ratings    0.971698
# dtype: float64

# %% [markdown]
# **Observations**
#
# 1. The delivery person columns are correlated to each other. This means that missingness in these columns is highly related which means lack of rider data.
# 2. The time ordered column is also related to the rider which shows that the data might be missing due to some network error where the system was unable to log rider details and time of order.
# 3. There is a very high correlation between weather patterns and the road traffic information. Be clear that this does not mean that the road traffic and weather columns are correlated. High corr in missingness means that if value in one column is missing, it is a high chance that it will be missing in others as well.
# 3. Road traffic density also shows correlation to the rider as it might be provided through the phone of rider (need to investigate).

# %% [markdown]
# ### Dendrogram

# %%
# dendrogram of missingness

msno.dendrogram(missing_df)
# Out:
# <Axes: >

# %%
# percentage of rows in the data having missing value

(missing_df.isna().any(axis=1).sum() / missing_df.shape[0]) * 100
# Out:
# 9.266773408198627

# %% [markdown]
# **About `9%` of the rows in the data have missing values**

# %% [markdown]
# # Basic Data Cleaning

# %%
# column names in data

df.columns.tolist()
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weatherconditions',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken(min)']

# %% [markdown]
# changing the column name of dataframe

# %%
def change_column_names(data: pd.DataFrame):
    return (
        data.rename(str.lower,axis=1)
        .rename({
            "delivery_person_id" : "rider_id",
            "delivery_person_age": "age",
            "delivery_person_ratings": "ratings",
            "delivery_location_latitude": "delivery_latitude",
            "delivery_location_longitude": "delivery_longitude",
            "time_orderd": "order_time",
            "time_order_picked": "order_picked_time",
            "weatherconditions": "weather",
            "road_traffic_density": "traffic",
            "city": "city_type",
            "time_taken(min)": "time_taken"},axis=1)
    )

# %%
# change column names

df = change_column_names(df)

# %%
df.head()
# Out:
#         id          rider_id age ratings  restaurant_latitude  \
# 0  0x4607    INDORES13DEL02   37     4.9            22.745049
# 1  0xb379    BANGRES18DEL02   34     4.5            12.913041
# 2  0x5d6d    BANGRES19DEL01   23     4.4            12.914264
# 3  0x7a6a   COIMBRES13DEL02   38     4.7            11.003669
# 4  0x70a2    CHENRES12DEL01   32     4.6            12.972793
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  19-03-2022
# 1             77.683237          13.043041           77.813237  25-03-2022
# 2             77.678400          12.924264           77.688400  19-03-2022
# 3             76.976494          11.053669           77.026494  05-04-2022
# 4             80.249982          13.012793           80.289982  26-03-2022
#
#   order_time order_picked_time                weather  traffic  \
# 0   11:30:00          11:45:00       conditions Sunny    High
# 1   19:45:00          19:50:00      conditions Stormy     Jam
# 2   08:30:00          08:45:00  conditions Sandstorms     Low
# 3   18:00:00          18:10:00       conditions Sunny  Medium
# 4   13:30:00          13:45:00      conditions Cloudy    High
#
#    vehicle_condition type_of_order type_of_vehicle multiple_deliveries  \
# 0                  2        Snack      motorcycle                    0
# 1                  2        Snack         scooter                    1
# 2                  0       Drinks      motorcycle                    1
# 3                  0       Buffet      motorcycle                    1
# 4                  1        Snack         scooter                    1
#
#   festival       city_type time_taken
# 0      No           Urban    (min) 24
# 1      No   Metropolitian    (min) 33
# 2      No           Urban    (min) 26
# 3      No   Metropolitian    (min) 21
# 4      No   Metropolitian    (min) 30

# %%
# check for duplicate rows

df.drop(columns=["id","rider_id"]).duplicated().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicate rows in the data**

# %% [markdown]
# ## Column Wise Cleaning

# %% [markdown]
# ### ID

# %%
# unique items in ID column

print(f"The number of unique IDs are {df['id'].nunique()}")
# Out:
# The number of unique IDs are 45593

# %% [markdown]
# **All the ID values are unique**
#
# This column can be dropped from the data

# %% [markdown]
# ### Rider Id

# %%
# unique rider ids in the column

df['rider_id'].nunique()
# Out:
# 1320

# %% [markdown]
# **The data contains 1320 unique riders**

# %%
# rider order count in data

df['rider_id'].value_counts()
# Out:
# rider_id
# PUNERES01DEL01     67
# JAPRES11DEL02      67
# HYDRES04DEL02      66
# JAPRES03DEL01      66
# VADRES11DEL02      66
#                    ..
# DEHRES18DEL03       7
# AURGRES11DEL03      7
# KOLRES09DEL03       6
# KOCRES16DEL03       6
# BHPRES010DEL03      5
# Name: count, Length: 1320, dtype: int64

# %% [markdown]
# the initial of rider_id contains the city name we will extract the city name from this

# %%
pd.Series(['PUNERES01DEL01']).str.split('RES').str[0]
# Out:
# 0    PUNE
# dtype: object

# %%
# extract city name out of rider id

(
    df['rider_id']
    .str.split("RES")
    .str.get(0)
    .rename("City_Name")
)
# Out:
# 0          INDO
# 1          BANG
# 2          BANG
# 3         COIMB
# 4          CHEN
#           ...
# 45588       JAP
# 45589       AGR
# 45590      CHEN
# 45591     COIMB
# 45592    RANCHI
# Name: City_Name, Length: 45593, dtype: object

# %% [markdown]
# ### Age

# %%
df['age']
# Out:
# 0        37
# 1        34
# 2        23
# 3        38
# 4        32
#          ..
# 45588    30
# 45589    21
# 45590    30
# 45591    20
# 45592    23
# Name: age, Length: 45593, dtype: object

# %%
# datatype

df['age'].dtype
# Out:
# dtype('O')

# %%
# min, mean and max values

df['age'].astype(float).describe()
# Out:
# count    43739.000000
# mean        29.567137
# std          5.815155
# min         15.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         50.000000
# Name: age, dtype: float64

# %% [markdown]
# **Minimum Rider age of 15 is concerning**
#
# Investigate further what type of transport is he using?

# %%
# boxplot of the age column

sns.boxplot(df['age'].astype(float))
# Out:
# <Axes: >

# %%
# rows of data where rider age is less than 18(minor)


minors_data = df.loc[df['age'].astype('float') < 18]

minors_data
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 2387    0x564      JAPRES15DEL03   15       1           -26.891191
# 2905    0xcd0    INDORES010DEL03   15       1            22.750040
# 2951    0x91a      SURRES17DEL03   15       1            21.149569
# 5902    0x474     CHENRES15DEL03   15       1            13.026286
# 9156    0x73f     BANGRES05DEL01   15       1            12.970324
# 10900  0x1b49      MUMRES14DEL02   15       1            19.181300
# 11125   0x40b      SURRES12DEL01   15       1           -21.183434
# 12093   0x523     INDORES03DEL02   15       1            22.751857
# 15124  0x18b0   RANCHIRES02DEL01   15       1             0.000000
# 15927   0x550     CHENRES08DEL02   15       1            13.022394
# 16084   0x58c      MUMRES02DEL01   15       1           -19.221315
# 16462   0xe4c      MYSRES05DEL03   15       1            12.323978
# 21222   0x3fc     BANGRES16DEL02   15       1            13.029198
# 22291   0x3ed   RANCHIRES09DEL01   15       1           -23.351058
# 23035   0x415      VADRES17DEL01   15       1             0.000000
# 23488  0x616c      SURRES07DEL02   15       1            21.170798
# 23644  0x1ea0     BANGRES17DEL02   15       1            12.972532
# 23664   0x3f7     CHENRES04DEL01   15       1           -13.029780
# 25873   0xbb3     CHENRES15DEL03   15       1            13.026286
# 26633   0x730     INDORES15DEL02   15       1            22.760072
# 26917   0x6e0     CHENRES06DEL03   15       1            13.054347
# 27118   0x3f2     BANGRES02DEL02   15       1            12.970221
# 27942   0x681     CHENRES07DEL03   15       1            13.081878
# 28003   0x406     PUNERES14DEL01   15       1            18.516216
# 29664  0x137e      MYSRES19DEL02   15       1            12.334022
# 31216  0x32aa      JAPRES11DEL01   15       1            26.902940
# 31959  0x4240     PUNERES05DEL02   15       1            18.543626
# 33198   0x622     CHENRES03DEL02   15       1           -13.091809
# 34953   0x85c    COIMBRES17DEL02   15       1            11.026117
# 36021   0xdc0    COIMBRES03DEL03   15       1            11.025083
# 37100   0x451      HYDRES14DEL03   15       1           -17.426228
# 37676   0x424     PUNERES20DEL02   15       1           -18.592718
# 39073   0x4a6    COIMBRES07DEL02   15       1           -10.961850
# 39082  0x1144      MYSRES05DEL01   15       1            12.323978
# 40285   0x442     CHENRES16DEL02   15       1           -13.049645
# 41241   0x49c    COIMBRES14DEL02   15       1            11.003681
# 44403  0x2314      VADRES04DEL01   15       1             0.000000
# 44881   0x8d4     CHENRES02DEL02   15       1            13.086438
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 2387              75.802083          26.981191           75.892083
# 2905              75.902847          22.810040           75.962847
# 2951              72.772697          21.209569           72.832697
# 5902              80.275235          13.056286           80.305235
# 9156              77.645748          13.080324           77.755748
# 10900             72.836191          19.231300           72.886191
# 11125            -72.814492          21.193434           72.824492
# 12093             75.866699          22.801857           75.916699
# 15124              0.000000           0.070000            0.070000
# 15927             80.242439          13.072394           80.292439
# 16084             72.862381          19.231315           72.872381
# 16462             76.627961          12.413978           76.717961
# 21222             77.570997          13.159198           77.700997
# 22291            -85.325731          23.421058           85.395731
# 23035              0.000000           0.070000            0.070000
# 23488             72.790489          21.220798           72.840489
# 23644             77.608179          13.022532           77.658179
# 23664            -80.208812          13.139780           80.318812
# 25873             80.275235          13.116286           80.365235
# 26633             75.892574          22.840072           75.972574
# 26917             80.257221          13.114347           80.317221
# 27118             77.645396          13.050221           77.725396
# 27942             80.248519          13.111878           80.278519
# 28003             73.842527          18.586216           73.912527
# 29664             76.618203          12.354022           76.638203
# 31216             75.793007          26.912940           75.803007
# 31959             73.905101          18.623626           73.985101
# 33198             80.219104          13.111809           80.239104
# 34953             76.944652          11.046117           76.964652
# 36021             77.015393          11.085083           77.075393
# 37100            -78.407495          17.486228           78.467495
# 37676            -73.773572          18.672718           73.853572
# 39073            -76.971082          11.091850           77.101082
# 39082             76.627961          12.433978           76.737961
# 40285            -80.242268          13.129645           80.322268
# 41241             76.975525          11.133681           77.105525
# 44403              0.000000           0.070000            0.070000
# 44881             80.220672          13.216439           80.350672
#
#        order_date order_time order_picked_time         weather traffic  \
# 2387   12-03-2022       NaN           17:20:00  conditions NaN    NaN
# 2905   03-04-2022       NaN           20:30:00  conditions NaN    NaN
# 2951   21-03-2022       NaN           22:10:00  conditions NaN    NaN
# 5902   11-03-2022       NaN           20:50:00  conditions NaN    NaN
# 9156   25-03-2022       NaN           23:25:00  conditions NaN    NaN
# 10900  30-03-2022       NaN           20:55:00  conditions NaN    NaN
# 11125  05-03-2022       NaN           11:30:00  conditions NaN    NaN
# 12093  24-03-2022       NaN           21:15:00  conditions NaN    NaN
# 15124  16-03-2022       NaN           23:55:00  conditions NaN    NaN
# 15927  11-03-2022       NaN           18:10:00  conditions NaN    NaN
# 16084  30-03-2022       NaN           12:05:00  conditions NaN    NaN
# 16462  27-03-2022       NaN           20:00:00  conditions NaN    NaN
# 21222  06-03-2022       NaN           17:15:00  conditions NaN    NaN
# 22291  27-03-2022       NaN           21:35:00  conditions NaN    NaN
# 23035  29-03-2022       NaN           00:00:00  conditions NaN    NaN
# 23488  24-03-2022       NaN           17:30:00  conditions NaN    NaN
# 23644  21-03-2022       NaN           17:40:00  conditions NaN    NaN
# 23664  31-03-2022       NaN           22:40:00  conditions NaN    NaN
# 25873  20-03-2022       NaN           22:50:00  conditions NaN    NaN
# 26633  12-03-2022       NaN           17:35:00  conditions NaN    NaN
# 26917  01-03-2022       NaN           18:20:00  conditions NaN    NaN
# 27118  02-03-2022       NaN           21:45:00  conditions NaN    NaN
# 27942  03-04-2022       NaN           21:50:00  conditions NaN    NaN
# 28003  27-03-2022       NaN           19:30:00  conditions NaN    NaN
# 29664  01-03-2022       NaN           09:35:00  conditions NaN    NaN
# 31216  09-03-2022       NaN           10:05:00  conditions NaN    NaN
# 31959  08-03-2022       NaN           21:25:00  conditions NaN    NaN
# 33198  03-03-2022       NaN           11:50:00  conditions NaN    NaN
# 34953  09-03-2022       NaN           09:10:00  conditions NaN    NaN
# 36021  03-03-2022       NaN           18:55:00  conditions NaN    NaN
# 37100  19-03-2022       NaN           19:05:00  conditions NaN    NaN
# 37676  16-03-2022       NaN           20:25:00  conditions NaN    NaN
# 39073  02-03-2022       NaN           19:55:00  conditions NaN    NaN
# 39082  29-03-2022       NaN           22:10:00  conditions NaN    NaN
# 40285  08-03-2022       NaN           23:05:00  conditions NaN    NaN
# 41241  02-04-2022       NaN           23:45:00  conditions NaN    NaN
# 44403  14-03-2022       NaN           17:40:00  conditions NaN    NaN
# 44881  18-03-2022       NaN           18:00:00  conditions NaN    NaN
#
#        vehicle_condition type_of_order    type_of_vehicle multiple_deliveries  \
# 2387                   3         Meal         motorcycle                    0
# 2905                   3        Snack            scooter                    1
# 2951                   3       Buffet            bicycle                    1
# 5902                   3       Drinks            bicycle                    1
# 9156                   3       Buffet         motorcycle                    2
# 10900                  3       Buffet         motorcycle                    1
# 11125                  3         Meal            scooter                    1
# 12093                  3       Buffet            bicycle                    0
# 15124                  3         Meal            bicycle                    1
# 15927                  3        Snack            bicycle                    0
# 16084                  3        Snack            scooter                    0
# 16462                  3         Meal   electric_scooter                    0
# 21222                  3       Drinks   electric_scooter                    0
# 22291                  3       Buffet   electric_scooter                    2
# 23035                  3        Snack            scooter                    0
# 23488                  3        Snack            scooter                    1
# 23644                  3       Drinks            bicycle                    1
# 23664                  3        Snack   electric_scooter                    1
# 25873                  3       Drinks            scooter                    0
# 26633                  3        Snack   electric_scooter                    1
# 26917                  3         Meal   electric_scooter                    1
# 27118                  3       Drinks   electric_scooter                    0
# 27942                  3       Buffet   electric_scooter                    1
# 28003                  3       Buffet            scooter                    1
# 29664                  3       Drinks            scooter                    1
# 31216                  3        Snack   electric_scooter                    1
# 31959                  3         Meal            bicycle                    0
# 33198                  3       Buffet            scooter                    0
# 34953                  3        Snack            scooter                    1
# 36021                  3         Meal         motorcycle                    1
# 37100                  3       Buffet   electric_scooter                    1
# 37676                  3       Buffet            scooter                    1
# 39073                  3       Drinks   electric_scooter                    0
# 39082                  3        Snack   electric_scooter                    0
# 40285                  3        Snack            bicycle                    0
# 41241                  3         Meal            scooter                    0
# 44403                  3       Drinks            scooter                    0
# 44881                  3        Snack   electric_scooter                    1
#
#       festival       city_type time_taken
# 2387       No           Urban    (min) 15
# 2905       No   Metropolitian    (min) 29
# 2951       No   Metropolitian    (min) 20
# 5902       No   Metropolitian    (min) 25
# 9156       No   Metropolitian    (min) 34
# 10900      No   Metropolitian    (min) 39
# 11125      No           Urban    (min) 27
# 12093      No   Metropolitian    (min) 28
# 15124      No   Metropolitian    (min) 21
# 15927      No   Metropolitian    (min) 17
# 16084      No   Metropolitian    (min) 23
# 16462      No           Urban    (min) 24
# 21222      No   Metropolitian    (min) 28
# 22291     Yes   Metropolitian    (min) 44
# 23035      No           Urban    (min) 27
# 23488      No   Metropolitian    (min) 32
# 23644      No   Metropolitian    (min) 23
# 23664      No           Urban    (min) 15
# 25873      No   Metropolitian    (min) 27
# 26633      No   Metropolitian    (min) 27
# 26917      No           Urban    (min) 21
# 27118      No           Urban    (min) 20
# 27942      No   Metropolitian    (min) 27
# 28003      No   Metropolitian    (min) 38
# 29664      No   Metropolitian    (min) 13
# 31216      No           Urban    (min) 19
# 31959      No   Metropolitian    (min) 21
# 33198      No   Metropolitian    (min) 33
# 34953      No   Metropolitian    (min) 19
# 36021      No   Metropolitian    (min) 28
# 37100      No           Urban    (min) 30
# 37676      No           Urban    (min) 30
# 39073      No   Metropolitian    (min) 24
# 39082      No   Metropolitian    (min) 30
# 40285      No   Metropolitian    (min) 25
# 41241      No   Metropolitian    (min) 25
# 44403      No   Metropolitian    (min) 34
# 44881      No           Urban    (min) 26

# %%
minors_data.shape
# Out:
# (38, 20)

# %%
minors_data.isnull().sum()
# Out:
# id                      0
# rider_id                0
# age                     0
# ratings                 0
# restaurant_latitude     0
# restaurant_longitude    0
# delivery_latitude       0
# delivery_longitude      0
# order_date              0
# order_time              0
# order_picked_time       0
# weather                 0
# traffic                 0
# vehicle_condition       0
# type_of_order           0
# type_of_vehicle         0
# multiple_deliveries     0
# festival                0
# city_type               0
# time_taken              0
# dtype: int64

# %% [markdown]
# **Observations**:
#
# 1. The star ratings of all the riders is 1.
# 2. The vehicle condition of these riders is very bad.
# 3. No weather and traffic conditions available.
# 4. Age of all these riders is 15 which is below the permissable age to drive a vehicle.
# 5. Latitude and Longitude values in negative which is not possible. India is situated above the equator so all latitudes should be positive and east of meridian line so longitudes are positive as well.

# %% [markdown]
# **Seems like removing this data for now makes more sense then fixing it because a lot of data is missing**

# %%
# rows of minors

minor_index = minors_data.index.tolist()

len(minor_index)
# Out:
# 38

# %% [markdown]
# ### Ratings

# %%
# datatype

df['ratings'].dtype
# Out:
# dtype('O')

# %%
# min, mean and max values

df['ratings'].astype(float).describe()
# Out:
# count    43685.000000
# mean         4.633780
# std          0.334716
# min          1.000000
# 25%          4.500000
# 50%          4.700000
# 75%          4.900000
# max          6.000000
# Name: ratings, dtype: float64

# %%
df['ratings'].value_counts()
# Out:
# ratings
# 4.8     7148
# 4.7     7142
# 4.9     7041
# 4.6     6940
# 5       3996
# 4.5     3303
# NaN     1908
# 4.1     1430
# 4.2     1418
# 4.3     1409
# 4.4     1361
# 4       1077
# 3.5      249
# 3.8      228
# 3.7      225
# 3.6      207
# 3.9      197
# 6         53
# 1         38
# 3.4       32
# 3.1       29
# 3.2       29
# 3.3       25
# 2.6       22
# 2.7       22
# 2.5       20
# 2.8       19
# 2.9       19
# 3          6
# Name: count, dtype: int64

# %%
df['ratings'].astype(float).value_counts(bins=[0,1, 2, 3, 4, 5, 6])
# Out:
# ratings
# (4.0, 5.0]       41188
# (3.0, 4.0]        2298
# (2.0, 3.0]         108
# (5.0, 6.0]          53
# (-0.001, 1.0]       38
# (1.0, 2.0]           0
# Name: count, dtype: int64

# %% [markdown]
# **6 Star rating is possibly a data error**

# %%
# boxplot

sns.boxplot(df['ratings'].astype(float))
# Out:
# <Axes: >

# %% [markdown]
# 1. **The Minors data have ratings as 1 which seems like an anomaly if we generally consider the ratings column distribution.**
#
# 2. **The rating of 6 is also one another anomaly in the data as maximum ratings are 5 and not more than that**
#     - Has to be investigated
#     - If data is problematic than fixing or removing is an option

# %%
# rows where the star rating is 6

six_star_data = df.loc[df['ratings'] == "6"]

len(six_star_data)
# Out:
# 53

# %%
six_star_data
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 3586    0x46d     BANGRES05DEL01   50       6           -12.970324
# 4714    0x493      HYDRES17DEL01   50       6           -17.451976
# 5169    0x4f2      JAPRES08DEL01   50       6           -26.910262
# 5362    0x430     BANGRES19DEL01   50       6            12.914264
# 5651   0xbef1      AGRRES13DEL02   50       6           -27.159795
# 6394    0x427      JAPRES06DEL02   50       6            26.911927
# 7031    0x3eb      MYSRES15DEL02   50       6           -12.352058
# 7681    0xd42      VADRES09DEL01   50       6             0.000000
# 9499    0x3f0    BANGRES010DEL01   50       6            12.933298
# 9535    0x3ef   RANCHIRES13DEL01   50       6           -23.374989
# 10100   0x5b0      MYSRES04DEL01   50       6            12.308500
# 10737  0xbffc      DEHRES18DEL02   50       6             0.000000
# 12297   0x940      SURRES02DEL02   50       6            21.186608
# 13257   0x490    COIMBRES03DEL02   50       6            11.025083
# 13652   0x434   RANCHIRES01DEL02   50       6           -23.416792
# 14106   0x3f6      MYSRES06DEL02   50       6            12.323994
# 14907   0x421     CHENRES19DEL01   50       6            12.986047
# 14944   0x43c      HYDRES14DEL01   50       6            17.426228
# 16798   0x3fa   RANCHIRES06DEL02   50       6            23.357804
# 17145   0x400    COIMBRES07DEL01   50       6            10.961850
# 17708   0x412    CHENRES010DEL01   50       6           -13.066762
# 18977  0xc363      BHPRES08DEL03   50       6            23.232537
# 19382   0x3fb     INDORES02DEL03   50       6           -22.651847
# 20269  0xd0bc      ALHRES01DEL02   50       6            25.454648
# 21320   0x810      HYDRES06DEL01   50       6            17.455894
# 22416  0xc7d6      ALHRES08DEL03   50       6            25.450329
# 23375  0x1060     BANGRES05DEL03   50       6            12.970324
# 24237   0x420      SURRES13DEL01   50       6           -21.170096
# 24918  0xbf34      KNPRES16DEL02   50       6            26.482581
# 25285   0x40c    COIMBRES08DEL03   50       6            11.001852
# 26052   0x694   RANCHIRES09DEL02   50       6            23.351058
# 27221   0x3f4    COIMBRES20DEL02   50       6           -10.994136
# 27399   0x3ea      MUMRES20DEL03   50       6            19.103249
# 28315   0x3fd     BANGRES13DEL01   50       6           -12.935662
# 28974   0x404     CHENRES04DEL01   50       6           -13.029780
# 29535   0x480     BANGRES15DEL01   50       6           -12.975377
# 30579  0xbf12      BHPRES20DEL03   50       6            23.235123
# 30943   0x4cc      MUMRES20DEL01   50       6           -19.103249
# 31233   0x706      VADRES09DEL02   50       6             0.000000
# 32326  0xbf33      KNPRES03DEL03   50       6           -26.469003
# 33533  0xbf01      KOLRES06DEL02   50       6           -22.533662
# 34688  0xbf76      AGRRES20DEL03   50       6           -27.158822
# 38007  0xbef2      DEHRES13DEL01   50       6            30.366322
# 38020   0x466     CHENRES14DEL02   50       6            13.026279
# 38561   0x3f1      VADRES09DEL03   50       6             0.000000
# 38649   0x5e0      MUMRES07DEL03   50       6           -19.091458
# 39699   0xa24   RANCHIRES14DEL03   50       6             0.000000
# 40223   0x3e9      MYSRES04DEL03   50       6           -12.308500
# 41105   0x4e4      VADRES17DEL01   50       6             0.000000
# 41969  0xbef4      KNPRES19DEL03   50       6           -26.490950
# 42072   0x5fc     INDORES11DEL03   50       6            22.751234
# 42835   0x53e     BANGRES12DEL01   50       6           -12.939496
# 45332  0x2950      VADRES04DEL02   50       6             0.000000
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 3586             -77.645748          13.010324           77.685748
# 4714             -78.385883          17.561976           78.495883
# 5169             -75.783013          27.020262           75.893013
# 5362              77.678400          13.024264           77.788400
# 5651             -78.042990          27.209795           78.092990
# 6394              75.797282          27.041927           75.927282
# 7031             -76.606650          12.372058           76.626650
# 7681               0.000000           0.010000            0.010000
# 9499              77.614293          13.003298           77.684293
# 9535             -85.335486          23.444989           85.405486
# 10100             76.665808          12.418500           76.775808
# 10737              0.000000           0.020000            0.020000
# 12297             72.794136          21.206608           72.814136
# 13257             77.015393          11.105083           77.095393
# 13652            -85.316842          23.466792           85.366842
# 14106             76.626167          12.373994           76.676167
# 14907             80.218114          12.996047           80.228114
# 14944             78.407495          17.536228           78.517495
# 16798             85.325146          23.377804           85.345146
# 17145             76.971082          10.971850           76.981082
# 17708            -80.251865          13.076762           80.261865
# 18977             77.429845          23.322537           77.519845
# 19382            -75.881991          22.711847           75.941991
# 20269             81.834502          25.504648           81.884502
# 21320             78.375467          17.525894           78.445467
# 22416             81.834279          25.590329           81.974279
# 23375             77.645748          13.030324           77.705748
# 24237            -72.789122          21.180096           72.799122
# 24918             80.315628          26.612581           80.445628
# 25285             76.976268          11.061852           77.036268
# 26052             85.325731          23.371058           85.345731
# 27221            -76.963303          11.074136           77.043303
# 27399             72.846749          19.133249           72.876749
# 28315            -77.614130          13.045662           77.724130
# 28974            -80.208812          13.099780           80.278812
# 29535            -77.696664          13.015377           77.736664
# 30579             77.398886          23.325123           77.488886
# 30943            -72.846749          19.213249           72.956749
# 31233              0.000000           0.050000            0.050000
# 32326            -80.316344          26.559003           80.406344
# 33533            -88.366217          22.663662           88.496217
# 34688            -78.045359          27.248822           78.135359
# 38007             78.070453          30.436322           78.140453
# 38020             80.174568          13.106279           80.254568
# 38561              0.000000           0.090000            0.090000
# 38649             72.827808          19.121458           72.857808
# 39699              0.000000           0.030000            0.030000
# 40223            -76.665808          12.398500           76.755808
# 41105              0.000000           0.110000            0.110000
# 41969            -80.318656          26.520950           80.348656
# 42072             75.889490          22.781234           75.919490
# 42835             77.625999          12.949496           77.635999
# 45332              0.000000           0.020000            0.020000
#
#        order_date order_time order_picked_time         weather traffic  \
# 3586   13-03-2022       NaN           12:30:00  conditions NaN    NaN
# 4714   04-04-2022       NaN           23:20:00  conditions NaN    NaN
# 5169   18-03-2022       NaN           18:50:00  conditions NaN    NaN
# 5362   06-04-2022       NaN           20:55:00  conditions NaN    NaN
# 5651   13-02-2022       NaN           18:05:00  conditions NaN    NaN
# 6394   02-04-2022       NaN           22:10:00  conditions NaN    NaN
# 7031   15-03-2022       NaN           10:00:00  conditions NaN    NaN
# 7681   21-03-2022       NaN           08:35:00  conditions NaN    NaN
# 9499   12-03-2022       NaN           18:25:00  conditions NaN    NaN
# 9535   20-03-2022       NaN           17:55:00  conditions NaN    NaN
# 10100  18-03-2022       NaN           20:10:00  conditions NaN    NaN
# 10737  13-02-2022       NaN           08:50:00  conditions NaN    NaN
# 12297  01-03-2022       NaN           11:25:00  conditions NaN    NaN
# 13257  23-03-2022       NaN           20:50:00  conditions NaN    NaN
# 13652  13-03-2022       NaN           20:40:00  conditions NaN    NaN
# 14106  03-03-2022       NaN           21:25:00  conditions NaN    NaN
# 14907  17-03-2022       NaN           09:35:00  conditions NaN    NaN
# 14944  02-04-2022       NaN           22:50:00  conditions NaN    NaN
# 16798  13-03-2022       NaN           09:05:00  conditions NaN    NaN
# 17145  05-03-2022       NaN           09:15:00  conditions NaN    NaN
# 17708  17-03-2022       NaN           09:15:00  conditions NaN    NaN
# 18977  18-02-2022       NaN           21:25:00  conditions NaN    NaN
# 19382  05-03-2022       NaN           19:30:00  conditions NaN    NaN
# 20269  15-02-2022       NaN           21:55:00  conditions NaN    NaN
# 21320  06-04-2022       NaN           17:30:00  conditions NaN    NaN
# 22416  16-02-2022       NaN           17:45:00  conditions NaN    NaN
# 23375  09-03-2022       NaN           22:15:00  conditions NaN    NaN
# 24237  15-03-2022       NaN           10:10:00  conditions NaN    NaN
# 24918  12-02-2022       NaN           18:30:00  conditions NaN    NaN
# 25285  01-03-2022       NaN           17:50:00  conditions NaN    NaN
# 26052  21-03-2022       NaN           08:40:00  conditions NaN    NaN
# 27221  06-03-2022       NaN           17:20:00  conditions NaN    NaN
# 27399  24-03-2022       NaN           23:20:00  conditions NaN    NaN
# 28315  06-03-2022       NaN           17:30:00  conditions NaN    NaN
# 28974  18-03-2022       NaN           23:55:00  conditions NaN    NaN
# 29535  01-03-2022       NaN           13:55:00  conditions NaN    NaN
# 30579  16-02-2022       NaN           23:10:00  conditions NaN    NaN
# 30943  16-03-2022       NaN           22:00:00  conditions NaN    NaN
# 31233  11-03-2022       NaN           22:30:00  conditions NaN    NaN
# 32326  14-02-2022       NaN           22:55:00  conditions NaN    NaN
# 33533  18-02-2022       NaN           21:50:00  conditions NaN    NaN
# 34688  14-02-2022       NaN           23:55:00  conditions NaN    NaN
# 38007  14-02-2022       NaN           18:05:00  conditions NaN    NaN
# 38020  20-03-2022       NaN           23:10:00  conditions NaN    NaN
# 38561  06-04-2022       NaN           19:20:00  conditions NaN    NaN
# 38649  11-03-2022       NaN           21:50:00  conditions NaN    NaN
# 39699  21-03-2022       NaN           21:10:00  conditions NaN    NaN
# 40223  12-03-2022       NaN           17:45:00  conditions NaN    NaN
# 41105  20-03-2022       NaN           21:55:00  conditions NaN    NaN
# 41969  13-02-2022       NaN           00:00:00  conditions NaN    NaN
# 42072  17-03-2022       NaN           20:40:00  conditions NaN    NaN
# 42835  19-03-2022       NaN           09:40:00  conditions NaN    NaN
# 45332  19-03-2022       NaN           10:40:00  conditions NaN    NaN
#
#        vehicle_condition type_of_order    type_of_vehicle multiple_deliveries  \
# 3586                   3         Meal   electric_scooter                    0
# 4714                   3        Snack            bicycle                    0
# 5169                   3       Drinks            scooter                    1
# 5362                   3         Meal   electric_scooter                    1
# 5651                   3       Drinks            scooter                    1
# 6394                   3         Meal   electric_scooter                    0
# 7031                   3       Buffet            scooter                    1
# 7681                   3         Meal            bicycle                    1
# 9499                   3       Drinks            scooter                    1
# 9535                   3        Snack            bicycle                    1
# 10100                  3        Snack   electric_scooter                    1
# 10737                  3        Snack            scooter                    0
# 12297                  3         Meal            scooter                    1
# 13257                  3       Buffet   electric_scooter                    1
# 13652                  3       Buffet         motorcycle                    0
# 14106                  3         Meal            scooter                    0
# 14907                  3       Drinks            bicycle                    0
# 14944                  3         Meal         motorcycle                    1
# 16798                  3       Drinks            scooter                    1
# 17145                  3        Snack   electric_scooter                    0
# 17708                  3       Drinks   electric_scooter                    1
# 18977                  3       Buffet            scooter                    1
# 19382                  3       Drinks            bicycle                    0
# 20269                  3        Snack         motorcycle                    1
# 21320                  3       Drinks   electric_scooter                    1
# 22416                  3       Drinks            scooter                    0
# 23375                  3       Buffet   electric_scooter                    0
# 24237                  3         Meal         motorcycle                    0
# 24918                  3       Buffet            scooter                    1
# 25285                  3         Meal   electric_scooter                    0
# 26052                  3         Meal   electric_scooter                    0
# 27221                  3       Drinks   electric_scooter                    0
# 27399                  3         Meal   electric_scooter                    1
# 28315                  3       Drinks   electric_scooter                    0
# 28974                  3         Meal   electric_scooter                    0
# 29535                  3       Drinks   electric_scooter                    1
# 30579                  3        Snack            bicycle                    2
# 30943                  3         Meal            scooter                    1
# 31233                  3       Drinks            scooter                    0
# 32326                  3       Drinks            scooter                    0
# 33533                  3        Snack            scooter                    1
# 34688                  3       Drinks   electric_scooter                    1
# 38007                  3        Snack   electric_scooter                    1
# 38020                  3         Meal            scooter                    0
# 38561                  3       Drinks   electric_scooter                    0
# 38649                  3       Buffet   electric_scooter                    1
# 39699                  3       Buffet            bicycle                    1
# 40223                  3       Drinks   electric_scooter                    1
# 41105                  3         Meal            scooter                    1
# 41969                  3       Drinks            scooter                    1
# 42072                  3       Buffet            scooter                    0
# 42835                  3       Drinks   electric_scooter                    1
# 45332                  3       Drinks   electric_scooter                    1
#
#       festival       city_type time_taken
# 3586       No           Urban    (min) 25
# 4714       No   Metropolitian    (min) 27
# 5169       No   Metropolitian    (min) 20
# 5362       No   Metropolitian    (min) 18
# 5651       No   Metropolitian    (min) 20
# 6394       No           Urban    (min) 20
# 7031       No   Metropolitian    (min) 14
# 7681       No   Metropolitian    (min) 22
# 9499       No           Urban    (min) 17
# 9535       No   Metropolitian    (min) 32
# 10100      No   Metropolitian    (min) 35
# 10737      No   Metropolitian    (min) 25
# 12297      No           Urban    (min) 22
# 13257      No           Urban    (min) 11
# 13652      No   Metropolitian    (min) 28
# 14106      No           Urban    (min) 15
# 14907      No   Metropolitian    (min) 12
# 14944      No           Urban    (min) 19
# 16798      No   Metropolitian    (min) 22
# 17145      No           Urban    (min) 14
# 17708      No   Metropolitian    (min) 20
# 18977      No   Metropolitian    (min) 17
# 19382      No   Metropolitian    (min) 30
# 20269      No           Urban    (min) 33
# 21320      No   Metropolitian    (min) 35
# 22416      No   Metropolitian    (min) 29
# 23375      No           Urban    (min) 19
# 24237      No   Metropolitian    (min) 17
# 24918      No   Metropolitian    (min) 41
# 25285      No   Metropolitian    (min) 16
# 26052      No   Metropolitian    (min) 20
# 27221      No             NaN    (min) 17
# 27399      No   Metropolitian    (min) 18
# 28315      No   Metropolitian    (min) 28
# 28974      No   Metropolitian    (min) 20
# 29535      No   Metropolitian    (min) 15
# 30579      No   Metropolitian    (min) 39
# 30943      No           Urban    (min) 30
# 31233      No   Metropolitian    (min) 28
# 32326      No             NaN    (min) 17
# 33533      No   Metropolitian    (min) 28
# 34688      No           Urban    (min) 16
# 38007      No   Metropolitian    (min) 25
# 38020      No   Metropolitian    (min) 14
# 38561      No   Metropolitian    (min) 36
# 38649      No           Urban    (min) 26
# 39699      No   Metropolitian    (min) 39
# 40223      No   Metropolitian    (min) 40
# 41105     Yes   Metropolitian    (min) 48
# 41969      No   Metropolitian    (min) 15
# 42072      No   Metropolitian    (min) 28
# 42835      No   Metropolitian    (min) 19
# 45332      No           Urban    (min) 28

# %%
six_star_index = six_star_data.index.tolist()

# %% [markdown]
# **Investigate further before action**
#
# Data removal seems logical at this stage.

# %% [markdown]
# ### Location Columns

# %% [markdown]
# I have a dataset which contains the longitude and latitude for restaurant and delivery and there full address which can be useful later on

# %%
location_subset=pd.read_csv("coordinates.csv")

# %%
location_subset.shape
# Out:
# (45593, 6)

# %%
df.shape
# Out:
# (45593, 20)

# %%
location_subset.head()
# Out:
#    restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 0            22.745049             75.892471          22.765049
# 1            12.913041             77.683237          13.043041
# 2            12.914264             77.678400          12.924264
# 3            11.003669             76.976494          11.053669
# 4            12.972793             80.249982          13.012793
#
#    delivery_longitude                            restaurant_full_address  \
# 0           75.912471  Indore City, Indore, Juni Indore Tahsil, Indor...
# 1           77.813237  Byg Brewsky, Sarjapura Road, Devarabeesanahall...
# 2           77.688400  The Hoot Cafe & Brewery, BBMP 2034/69,Sarjapur...
# 3           77.026494  Bishop Appasamy College, Thirugnanasambandam R...
# 4           80.289982  Jayendra Colony, Ward 183, Zone 14 Perungudi, ...
#
#                                delivery_full_address
# 0  Balaji Heights, Piplya Kumar, Indore, Juni Ind...
# 1  Ganagaluru, Hosakote taluk, Bengaluru Rural, K...
# 2  Cadence Design Systems (India) Private Limited...
# 3  Ward 36, East Zone, Coimbatore, Coimbatore Nor...
# 4  Urur Kuppam, Ward 176, Zone 13 Adyar, Chennai,...

# %%
df.head()
# Out:
#         id          rider_id age ratings  restaurant_latitude  \
# 0  0x4607    INDORES13DEL02   37     4.9            22.745049
# 1  0xb379    BANGRES18DEL02   34     4.5            12.913041
# 2  0x5d6d    BANGRES19DEL01   23     4.4            12.914264
# 3  0x7a6a   COIMBRES13DEL02   38     4.7            11.003669
# 4  0x70a2    CHENRES12DEL01   32     4.6            12.972793
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  19-03-2022
# 1             77.683237          13.043041           77.813237  25-03-2022
# 2             77.678400          12.924264           77.688400  19-03-2022
# 3             76.976494          11.053669           77.026494  05-04-2022
# 4             80.249982          13.012793           80.289982  26-03-2022
#
#   order_time order_picked_time                weather  traffic  \
# 0   11:30:00          11:45:00       conditions Sunny    High
# 1   19:45:00          19:50:00      conditions Stormy     Jam
# 2   08:30:00          08:45:00  conditions Sandstorms     Low
# 3   18:00:00          18:10:00       conditions Sunny  Medium
# 4   13:30:00          13:45:00      conditions Cloudy    High
#
#    vehicle_condition type_of_order type_of_vehicle multiple_deliveries  \
# 0                  2        Snack      motorcycle                    0
# 1                  2        Snack         scooter                    1
# 2                  0       Drinks      motorcycle                    1
# 3                  0       Buffet      motorcycle                    1
# 4                  1        Snack         scooter                    1
#
#   festival       city_type time_taken
# 0      No           Urban    (min) 24
# 1      No   Metropolitian    (min) 33
# 2      No           Urban    (min) 26
# 3      No   Metropolitian    (min) 21
# 4      No   Metropolitian    (min) 30

# %%
location_subset.isna().sum()
# Out:
# restaurant_latitude           0
# restaurant_longitude          0
# delivery_latitude             0
# delivery_longitude            0
# restaurant_full_address    3674
# delivery_full_address      3674
# dtype: int64

# %%
location_subset[location_subset['delivery_full_address'].isna()]
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 33                     0.0                   0.0               0.11
# 52                     0.0                   0.0               0.03
# 57                     0.0                   0.0               0.08
# 59                     0.0                   0.0               0.06
# 67                     0.0                   0.0               0.02
# ...                    ...                   ...                ...
# 45569                  0.0                   0.0               0.07
# 45576                  0.0                   0.0               0.13
# 45577                  0.0                   0.0               0.09
# 45579                  0.0                   0.0               0.05
# 45589                  0.0                   0.0               0.07
#
#        delivery_longitude restaurant_full_address delivery_full_address
# 33                   0.11                     NaN                   NaN
# 52                   0.03                     NaN                   NaN
# 57                   0.08                     NaN                   NaN
# 59                   0.06                     NaN                   NaN
# 67                   0.02                     NaN                   NaN
# ...                   ...                     ...                   ...
# 45569                0.07                     NaN                   NaN
# 45576                0.13                     NaN                   NaN
# 45577                0.09                     NaN                   NaN
# 45579                0.05                     NaN                   NaN
# 45589                0.07                     NaN                   NaN
#
# [3674 rows x 6 columns]

# %% [markdown]
# **Valid values for lat and long**
#
#  > India lies to the north of the equator between `6° 44′` and `35° 30′` north latitude and `68° 7′` and `97° 25′` east longitude.

# %%
df[['restaurant_latitude', 'restaurant_longitude', 'delivery_latitude', 'delivery_longitude']].describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         45593.000000          45593.000000       45593.000000
# mean             17.017729             70.231332          17.465186
# std               8.185109             22.883647           7.335122
# min             -30.905562            -88.366217           0.010000
# 25%              12.933284             73.170000          12.988453
# 50%              18.546947             75.898497          18.633934
# 75%              22.728163             78.044095          22.785049
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        45593.000000
# mean            70.845702
# std             21.118812
# min              0.010000
# 25%             73.280000
# 50%             76.002574
# 75%             78.107044
# max             88.563452

# %%
# statistical analysis

location_subset.describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         45593.000000          45593.000000       45593.000000
# mean             17.401571             70.782088          17.465186
# std               7.333766             21.118611           7.335122
# min               0.000000              0.000000           0.010000
# 25%              12.934179             73.170283          12.988453
# 50%              18.554382             75.898497          18.633934
# 75%              22.732225             78.046106          22.785049
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        45593.000000
# mean            70.845702
# std             21.118812
# min              0.010000
# 25%             73.280000
# 50%             76.002574
# 75%             78.107044
# max             88.563452

# %%
# set the lower bound limits for the lat and long

lower_bound_lat = 6.44
lower_bound_long = 68.70

# %%
# rows of data where latitude and longitude values are below the bounds

df.loc[
    (df['restaurant_latitude'] < lower_bound_lat) |
    (df['restaurant_longitude'] < lower_bound_long) |
    (df['delivery_latitude'] < lower_bound_lat) |
    (df['delivery_longitude'] < lower_bound_long)
].sample(10)
# Out:
#             id           rider_id   age ratings  restaurant_latitude  \
# 17769  0x3630      MYSRES14DEL01     27     4.7             0.000000
# 17528  0xd6e1      AGRRES06DEL01     29       5             0.000000
# 37214  0xc08a      KOLRES07DEL03     31     4.6           -22.547186
# 24727  0x5a2a      VADRES17DEL03     25     4.5             0.000000
# 23588  0xc024      KOCRES05DEL03     36    NaN             -9.970717
# 23073   0x4f7     BANGRES03DEL01   NaN     NaN            -12.979166
# 26146  0x3863   RANCHIRES03DEL03     21     4.5             0.000000
# 6071   0x3c3c      VADRES08DEL01     32     4.8             0.000000
# 37556  0x251e   RANCHIRES14DEL02     37       5             0.000000
# 19657  0xd7ed      GOARES20DEL02     37     4.8             0.000000
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 17769              0.000000           0.010000            0.010000
# 17528              0.000000           0.010000            0.010000
# 37214             88.350680          22.607185           88.410680
# 24727              0.000000           0.060000            0.060000
# 23588             76.285447          10.000717           76.315447
# 23073            -77.640709          13.089166           77.750709
# 26146              0.000000           0.090000            0.090000
# 6071               0.000000           0.040000            0.040000
# 37556              0.000000           0.020000            0.020000
# 19657              0.000000           0.050000            0.050000
#
#        order_date order_time order_picked_time            weather  traffic  \
# 17769  30-03-2022   10:15:00          10:30:00   conditions Windy     Low
# 17528  15-02-2022   09:00:00          09:15:00   conditions Sunny     Low
# 37214  11-02-2022   18:00:00          18:15:00   conditions Sunny  Medium
# 24727  24-03-2022   23:35:00          23:50:00   conditions Windy     Low
# 23588  17-02-2022   21:25:00          21:30:00   conditions Windy     Jam
# 23073  02-04-2022       NaN           22:20:00     conditions NaN     NaN
# 26146  25-03-2022   18:45:00          18:50:00   conditions Sunny  Medium
# 6071   26-03-2022   15:30:00          15:45:00  conditions Stormy  Medium
# 37556  09-03-2022   10:30:00          10:35:00  conditions Cloudy     Low
# 19657  15-02-2022   18:15:00          18:20:00  conditions Cloudy  Medium
#
#        vehicle_condition type_of_order    type_of_vehicle multiple_deliveries  \
# 17769                  1       Drinks         motorcycle                    1
# 17528                  1        Snack            scooter                    1
# 37214                  2       Buffet   electric_scooter                    1
# 24727                  1         Meal         motorcycle                    0
# 23588                  1       Buffet         motorcycle                    1
# 23073                  3        Snack   electric_scooter                    1
# 26146                  2       Drinks            scooter                    0
# 6071                   0        Snack         motorcycle                    0
# 37556                  2       Drinks            scooter                    0
# 19657                  2         Meal         motorcycle                    0
#
#       festival       city_type time_taken
# 17769      No           Urban    (min) 11
# 17528      No           Urban    (min) 23
# 37214      No   Metropolitian    (min) 15
# 24727      No   Metropolitian    (min) 13
# 23588      No   Metropolitian    (min) 28
# 23073      No   Metropolitian    (min) 29
# 26146      No   Metropolitian    (min) 11
# 6071       No   Metropolitian    (min) 28
# 37556      No           Urban    (min) 19
# 19657      No           Urban    (min) 15

# %%
# number of rows in data where lat long are erroneous

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].shape[0]
# Out:
# 3640

# %%
# rows of data where latitude and longitude values are below the bounds

df.loc[
    (df['restaurant_latitude'] < lower_bound_lat) |
    (df['restaurant_longitude'] < lower_bound_long) |
    (df['delivery_latitude'] < lower_bound_lat) |
    (df['delivery_longitude'] < lower_bound_long)
].shape
# Out:
# (4071, 20)

# %% [markdown]
# **There are 4071 rows in the data where the lat long columns are messy**

# %%
# statistical summary of problematic rows where lat long is below the country's geographical limits

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count               3640.0                3640.0        3640.000000
# mean                   0.0                   0.0           0.063016
# std                    0.0                   0.0           0.036047
# min                    0.0                   0.0           0.010000
# 25%                    0.0                   0.0           0.030000
# 50%                    0.0                   0.0           0.060000
# 75%                    0.0                   0.0           0.090000
# max                    0.0                   0.0           0.130000
#
#        delivery_longitude
# count         3640.000000
# mean             0.063016
# std              0.036047
# min              0.010000
# 25%              0.030000
# 50%              0.060000
# 75%              0.090000
# max              0.130000

# %%
# boxplots for all the anomalies

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].plot(kind="box")

plt.xticks(rotation=45)
# Out:
# (array([1, 2, 3, 4]),
#  [Text(1, 0, 'restaurant_latitude'),
#   Text(2, 0, 'restaurant_longitude'),
#   Text(3, 0, 'delivery_latitude'),
#   Text(4, 0, 'delivery_longitude')])

# %% [markdown]
# **Negative Values are correct just we have to take absolute**
#
# **While calculating the distances we can assign null values to these erroneous data points and then impute the values using advanced imputation techniques**

# %%
# taking the absolute values

(
    location_subset
    .plot(kind="box")
)

ax = plt.gca()

ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(1, 0, 'restaurant_latitude'),
#  Text(2, 0, 'restaurant_longitude'),
#  Text(3, 0, 'delivery_latitude'),
#  Text(4, 0, 'delivery_longitude')]

# %%
# number of rows after taking absolute values

(
    location_subset
    .loc[lambda df_:
        (df_['restaurant_latitude'] < lower_bound_lat) |
        (df_['restaurant_longitude'] < lower_bound_long) |
        (df_['delivery_latitude'] < lower_bound_lat) |
        (df_['delivery_longitude'] < lower_bound_long)]
    .shape[0]

)
# Out:
# 3640

# %% [markdown]
# **`3640` rows in the data that have messy lat long values**

# %%
# lat long values less than 1

location_subset.loc[lambda df_:
                        (df_['restaurant_latitude'] < 1) |
                        (df_['restaurant_longitude'] < 1) |
                        (df_['delivery_latitude'] < 1) |
                        (df_['delivery_longitude'] < 1)]
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 33                     0.0                   0.0               0.11
# 52                     0.0                   0.0               0.03
# 57                     0.0                   0.0               0.08
# 59                     0.0                   0.0               0.06
# 67                     0.0                   0.0               0.02
# ...                    ...                   ...                ...
# 45569                  0.0                   0.0               0.07
# 45576                  0.0                   0.0               0.13
# 45577                  0.0                   0.0               0.09
# 45579                  0.0                   0.0               0.05
# 45589                  0.0                   0.0               0.07
#
#        delivery_longitude restaurant_full_address delivery_full_address
# 33                   0.11                     NaN                   NaN
# 52                   0.03                     NaN                   NaN
# 57                   0.08                     NaN                   NaN
# 59                   0.06                     NaN                   NaN
# 67                   0.02                     NaN                   NaN
# ...                   ...                     ...                   ...
# 45569                0.07                     NaN                   NaN
# 45576                0.13                     NaN                   NaN
# 45577                0.09                     NaN                   NaN
# 45579                0.05                     NaN                   NaN
# 45589                0.07                     NaN                   NaN
#
# [3640 rows x 6 columns]

# %% [markdown]
# **All the messy lat long values are less than 1**

# %%
location_subset.columns.tolist()[:-2]
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude']

# %%
def clean_lat_long(data: pd.DataFrame, threshold=1):
    location_columns = location_subset.columns.tolist()[:-2]

    return (
        data
        .assign(**{
            col: (
                np.where(data[col] < threshold, np.NaN, data[col].values)
            )
            for col in location_columns
        })
    )

# %%
df
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 0      0x4607     INDORES13DEL02   37     4.9            22.745049
# 1      0xb379     BANGRES18DEL02   34     4.5            12.913041
# 2      0x5d6d     BANGRES19DEL01   23     4.4            12.914264
# 3      0x7a6a    COIMBRES13DEL02   38     4.7            11.003669
# 4      0x70a2     CHENRES12DEL01   32     4.6            12.972793
# ...        ...                ...  ..     ...                  ...
# 45588  0x7c09      JAPRES04DEL01   30     4.8            26.902328
# 45589  0xd641      AGRRES16DEL01   21     4.6             0.000000
# 45590  0x4f8d     CHENRES08DEL03   30     4.9            13.022394
# 45591  0x5eee    COIMBRES11DEL01   20     4.7            11.001753
# 45592  0x5fb2   RANCHIRES09DEL02   23     4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45588             75.794257          26.912328           75.804257
# 45589              0.000000           0.070000            0.070000
# 45590             80.242439          13.052394           80.272439
# 45591             76.986241          11.041753           77.026241
# 45592             85.325731          23.431058           85.405731
#
#        order_date order_time order_picked_time                weather  \
# 0      19-03-2022   11:30:00          11:45:00       conditions Sunny
# 1      25-03-2022   19:45:00          19:50:00      conditions Stormy
# 2      19-03-2022   08:30:00          08:45:00  conditions Sandstorms
# 3      05-04-2022   18:00:00          18:10:00       conditions Sunny
# 4      26-03-2022   13:30:00          13:45:00      conditions Cloudy
# ...           ...        ...               ...                    ...
# 45588  24-03-2022   11:35:00          11:45:00       conditions Windy
# 45589  16-02-2022   19:55:00          20:10:00       conditions Windy
# 45590  11-03-2022   23:50:00          00:05:00      conditions Cloudy
# 45591  07-03-2022   13:35:00          13:40:00      conditions Cloudy
# 45592  02-03-2022   17:10:00          17:15:00         conditions Fog
#
#        traffic  vehicle_condition type_of_order type_of_vehicle  \
# 0        High                   2        Snack      motorcycle
# 1         Jam                   2        Snack         scooter
# 2         Low                   0       Drinks      motorcycle
# 3      Medium                   0       Buffet      motorcycle
# 4        High                   1        Snack         scooter
# ...        ...                ...           ...             ...
# 45588    High                   1         Meal      motorcycle
# 45589     Jam                   0       Buffet      motorcycle
# 45590     Low                   1       Drinks         scooter
# 45591    High                   0        Snack      motorcycle
# 45592  Medium                   2        Snack         scooter
#
#       multiple_deliveries festival       city_type time_taken
# 0                       0      No           Urban    (min) 24
# 1                       1      No   Metropolitian    (min) 33
# 2                       1      No           Urban    (min) 26
# 3                       1      No   Metropolitian    (min) 21
# 4                       1      No   Metropolitian    (min) 30
# ...                   ...      ...             ...        ...
# 45588                   0      No   Metropolitian    (min) 32
# 45589                   1      No   Metropolitian    (min) 36
# 45590                   0      No   Metropolitian    (min) 16
# 45591                   1      No   Metropolitian    (min) 26
# 45592                   1      No   Metropolitian    (min) 36
#
# [45593 rows x 20 columns]

# %%
clean_lat_long(df).isna().sum()
# Out:
# id                         0
# rider_id                   0
# age                        0
# ratings                    0
# restaurant_latitude     4071
# restaurant_longitude    3802
# delivery_latitude       3640
# delivery_longitude      3640
# order_date                 0
# order_time                 0
# order_picked_time          0
# weather                    0
# traffic                    0
# vehicle_condition          0
# type_of_order              0
# type_of_vehicle            0
# multiple_deliveries        0
# festival                   0
# city_type                  0
# time_taken                 0
# dtype: int64

# %% [markdown]
# ### Order Date

# %%
# check for missing values

df['order_date'].isna().sum()
# Out:
# 0

# %%
# unique values in order date

df['order_date'].unique()
# Out:
# array(['19-03-2022', '25-03-2022', '05-04-2022', '26-03-2022',
#        '11-03-2022', '04-03-2022', '14-03-2022', '20-03-2022',
#        '12-02-2022', '13-02-2022', '14-02-2022', '02-04-2022',
#        '01-03-2022', '16-03-2022', '15-02-2022', '10-03-2022',
#        '27-03-2022', '12-03-2022', '01-04-2022', '05-03-2022',
#        '11-02-2022', '08-03-2022', '03-04-2022', '30-03-2022',
#        '28-03-2022', '18-03-2022', '06-04-2022', '04-04-2022',
#        '24-03-2022', '09-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
# date range

order_date = pd.to_datetime(df['order_date'],dayfirst=True)

order_date.max() - order_date.min()
# Out:
# Timedelta('54 days 00:00:00')

# %% [markdown]
# we have a data of 54 days

# %%
# min and maximum dates

order_date.agg(["min","max"]).set_axis(["start","end"],axis=0)
# Out:
# start   2022-02-11
# end     2022-04-06
# Name: order_date, dtype: datetime64[ns]

# %%
# extract day, day name, month and year

def extract_datetime_features(ser):
    date_col = pd.to_datetime(ser,dayfirst=True)

    return (
        pd.DataFrame(
            {
                "day": date_col.dt.day,
                "month": date_col.dt.month,
                "year": date_col.dt.year,
                "day_of_week": date_col.dt.day_name(),
                "is_weekend": date_col.dt.day_name().isin(["Saturday","Sunday"]).astype(int)
            }
        ))

# %%
extract_datetime_features(df['order_date'])
# Out:
#        day  month  year day_of_week  is_weekend
# 0       19      3  2022    Saturday           1
# 1       25      3  2022      Friday           0
# 2       19      3  2022    Saturday           1
# 3        5      4  2022     Tuesday           0
# 4       26      3  2022    Saturday           1
# ...    ...    ...   ...         ...         ...
# 45588   24      3  2022    Thursday           0
# 45589   16      2  2022   Wednesday           0
# 45590   11      3  2022      Friday           0
# 45591    7      3  2022      Monday           0
# 45592    2      3  2022   Wednesday           0
#
# [45593 rows x 5 columns]

# %% [markdown]
# ### Order time and Order picked time

# %%
# extract hour info from data

order_time_hr = pd.to_datetime(df.replace("NaN ",np.NaN)['order_time'],format='mixed').dt.hour

order_time_hr
# Out:
# 0        11.0
# 1        19.0
# 2         8.0
# 3        18.0
# 4        13.0
#          ...
# 45588    11.0
# 45589    19.0
# 45590    23.0
# 45591    13.0
# 45592    17.0
# Name: order_time, Length: 45593, dtype: float64

# %%
def time_of_day(ser):
    time_col = pd.to_datetime(ser,format='mixed').dt.hour

    return(
        np.select(condlist=[(ser.between(6,12,inclusive='left')),
                            (ser.between(12,17,inclusive='left')),
                            (ser.between(17,20,inclusive='left')),
                            (ser.between(20,24,inclusive='left'))],
                  choicelist=["morning","afternoon","evening","night"],
                  default="after_midnight")
    )

# %%
time_subset = df.loc[:,["order_time","order_picked_time"]]
time_subset
# Out:
#       order_time order_picked_time
# 0       11:30:00          11:45:00
# 1       19:45:00          19:50:00
# 2       08:30:00          08:45:00
# 3       18:00:00          18:10:00
# 4       13:30:00          13:45:00
# ...          ...               ...
# 45588   11:35:00          11:45:00
# 45589   19:55:00          20:10:00
# 45590   23:50:00          00:05:00
# 45591   13:35:00          13:40:00
# 45592   17:10:00          17:15:00
#
# [45593 rows x 2 columns]

# %%
(
    time_subset
    .dtypes
)
# Out:
# order_time           object
# order_picked_time    object
# dtype: object

# %%
time_subset.columns.tolist()
# Out:
# ['order_time', 'order_picked_time']

# %%
# calculate the pickup time

(
    time_subset
    .assign(**{
        col: pd.to_datetime(time_subset[col].replace("NaN ",np.NaN).dropna(),format="mixed")
        for col in time_subset.columns.tolist()}
    )
    .assign(
        pickup_time = lambda x: (x['order_picked_time'] - x['order_time']).dt.seconds / 60,
        order_time_hour = lambda x: x['order_time'].dt.hour,
        order_time_of_day = lambda x: x['order_time_hour'].pipe(time_of_day)
    )
    .drop(columns=["order_time","order_picked_time"])
)
# Out:
#        pickup_time  order_time_hour order_time_of_day
# 0             15.0             11.0           morning
# 1              5.0             19.0           evening
# 2             15.0              8.0           morning
# 3             10.0             18.0           evening
# 4             15.0             13.0         afternoon
# ...            ...              ...               ...
# 45588         10.0             11.0           morning
# 45589         15.0             19.0           evening
# 45590         15.0             23.0             night
# 45591          5.0             13.0         afternoon
# 45592          5.0             17.0           evening
#
# [45593 rows x 3 columns]

# %% [markdown]
# ### Weather

# %%
# value counts

df['weather'].value_counts()
# Out:
# weather
# conditions Fog           7654
# conditions Stormy        7586
# conditions Cloudy        7536
# conditions Sandstorms    7495
# conditions Windy         7422
# conditions Sunny         7284
# conditions NaN            616
# Name: count, dtype: int64

# %%
# unique values
df['weather'].unique()
# Out:
# array(['conditions Sunny', 'conditions Stormy', 'conditions Sandstorms',
#        'conditions Cloudy', 'conditions Fog', 'conditions Windy',
#        'conditions NaN'], dtype=object)

# %%
# remove conditions from values

(
    df['weather']
    .str.replace("conditions ","")
    .unique()
)
# Out:
# array(['Sunny', 'Stormy', 'Sandstorms', 'Cloudy', 'Fog', 'Windy', 'NaN'],
#       dtype=object)

# %% [markdown]
# ### Traffic

# %%
# value counts

df['traffic'].value_counts()
# Out:
# traffic
# Low        15477
# Jam        14143
# Medium     10947
# High        4425
# NaN          601
# Name: count, dtype: int64

# %%
# unique values
df['traffic'].unique()
# Out:
# array(['High ', 'Jam ', 'Low ', 'Medium ', 'NaN '], dtype=object)

# %%
(
    df['traffic']
    .replace("NaN ",np.NaN)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['high', 'jam', 'low', 'medium', nan], dtype=object)

# %% [markdown]
# ### Vehicle Condition

# %%
# unique values in column

np.sort(df['vehicle_condition'].unique())
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %% [markdown]
# ### Type of order

# %%
# value counts

df['type_of_order'].value_counts()
# Out:
# type_of_order
# Snack      11533
# Meal       11458
# Drinks     11322
# Buffet     11280
# Name: count, dtype: int64

# %%
# unique values
df['type_of_order'].unique()
# Out:
# array(['Snack ', 'Drinks ', 'Buffet ', 'Meal '], dtype=object)

# %%
(
    df['type_of_order']
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['snack', 'drinks', 'buffet', 'meal'], dtype=object)

# %% [markdown]
# ### Type of vehicle

# %%
# value counts

df['type_of_vehicle'].value_counts()
# Out:
# type_of_vehicle
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: count, dtype: int64

# %%
# unique values
df['type_of_vehicle'].unique()
# Out:
# array(['motorcycle ', 'scooter ', 'electric_scooter ', 'bicycle '],
#       dtype=object)

# %%
(
    df['type_of_vehicle']
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter', 'bicycle'],
#       dtype=object)

# %% [markdown]
# ### Multiple Deliveries

# %%
# datatype of multiple deliveries column

df['multiple_deliveries'].dtype
# Out:
# dtype('O')

# %%
# unique values in column

df['multiple_deliveries'].unique()
# Out:
# array(['0', '1', '3', 'NaN ', '2'], dtype=object)

# %%
# make the column as integer

(
    df['multiple_deliveries']
    .replace("NaN ",np.NaN)
    .astype(float)
    .unique()
)
# Out:
# array([ 0.,  1.,  3., nan,  2.])

# %% [markdown]
# ### Festival

# %%
# unique values in column

df['festival'].unique()
# Out:
# array(['No ', 'Yes ', 'NaN '], dtype=object)

# %%
(
    df['festival']
    .replace("NaN ",np.NaN)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['no', 'yes', nan], dtype=object)

# %% [markdown]
# ### City type

# %%
# unique values in city type

df['city_type'].unique()
# Out:
# array(['Urban ', 'Metropolitian ', 'Semi-Urban ', 'NaN '], dtype=object)

# %%
(
    df['city_type']
    .replace("NaN ",np.NaN)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['urban', 'metropolitian', 'semi-urban', nan], dtype=object)

# %% [markdown]
# ### Time Taken

# %%
# datatype of time taken

df['time_taken'].dtype
# Out:
# dtype('O')

# %%
(
    df['time_taken']
    .str.replace("(min) ","")
    .astype(int)
)
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45588    32
# 45589    36
# 45590    16
# 45591    26
# 45592    36
# Name: time_taken, Length: 45593, dtype: int32

# %% [markdown]
# ## Perform Cleaning and Feature Building

# %%
df.columns
# Out:
# Index(['id', 'rider_id', 'age', 'ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_latitude', 'delivery_longitude',
#        'order_date', 'order_time', 'order_picked_time', 'weather', 'traffic',
#        'vehicle_condition', 'type_of_order', 'type_of_vehicle',
#        'multiple_deliveries', 'festival', 'city_type', 'time_taken'],
#       dtype='object')

# %%
def data_cleaning(data: pd.DataFrame):

    return (
        data
        .drop(columns="id")
        .drop(index=minor_index)                                                # Minor riders in data dropped
        .drop(index=six_star_index)                                             # six star rated drivers dropped
        .replace("NaN ",np.NaN)                                                 # missing values in the data
        .assign(
            # city column out of rider id
            city_name = lambda x: x['rider_id'].str.split("RES").str.get(0),
            # convert age to float
            age = lambda x: x['age'].astype(float),
            # convert ratings to float
            ratings = lambda x: x['ratings'].astype(float),
            # absolute values for location based columns
            restaurant_latitude = lambda x: x['restaurant_latitude'].abs(),
            restaurant_longitude = lambda x: x['restaurant_longitude'].abs(),
            delivery_latitude = lambda x: x['delivery_latitude'].abs(),
            delivery_longitude = lambda x: x['delivery_longitude'].abs(),
            # order date to datetime and feature extraction
            order_date = lambda x: pd.to_datetime(x['order_date'],
                                                  dayfirst=True),
            order_day = lambda x: x['order_date'].dt.day,
            order_month = lambda x: x['order_date'].dt.month,
            order_day_of_week = lambda x: x['order_date'].dt.day_name().str.lower(),
            is_weekend = lambda x: (x['order_date']
                                    .dt.day_name()
                                    .isin(["Saturday","Sunday"])
                                    .astype(int)),
            # time based columns
            order_time = lambda x: pd.to_datetime(x['order_time'],
                                                  format='mixed'),
            order_picked_time = lambda x: pd.to_datetime(x['order_picked_time'],
                                                         format='mixed'),
            # time taken to pick order
            pickup_time_minutes = lambda x: (
                                            (x['order_picked_time'] - x['order_time'])
                                            .dt.seconds / 60
                                            ),
            # hour in which order was placed
            order_time_hour = lambda x: x['order_time'].dt.hour,
            # time of the day when order was placed
            order_time_of_day = lambda x: (
                                x['order_time_hour'].pipe(time_of_day)),
            # categorical columns
            weather = lambda x: (
                                x['weather']
                                .str.replace("conditions ","")
                                .str.lower()
                                .replace("nan",np.NaN)),
            traffic = lambda x: x["traffic"].str.rstrip().str.lower(),
            type_of_order = lambda x: x['type_of_order'].str.rstrip().str.lower(),
            type_of_vehicle = lambda x: x['type_of_vehicle'].str.rstrip().str.lower(),
            festival = lambda x: x['festival'].str.rstrip().str.lower(),
            city_type = lambda x: x['city_type'].str.rstrip().str.lower(),
            # multiple deliveries column
            multiple_deliveries = lambda x: x['multiple_deliveries'].astype(float),
            # target column modifications
            time_taken = lambda x: (x['time_taken']
                                    .str.replace("(min) ","")
                                    .astype(int)))
        .drop(columns=["order_time","order_picked_time"])
    )

# %%
df
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 0      0x4607     INDORES13DEL02   37     4.9            22.745049
# 1      0xb379     BANGRES18DEL02   34     4.5            12.913041
# 2      0x5d6d     BANGRES19DEL01   23     4.4            12.914264
# 3      0x7a6a    COIMBRES13DEL02   38     4.7            11.003669
# 4      0x70a2     CHENRES12DEL01   32     4.6            12.972793
# ...        ...                ...  ..     ...                  ...
# 45588  0x7c09      JAPRES04DEL01   30     4.8            26.902328
# 45589  0xd641      AGRRES16DEL01   21     4.6             0.000000
# 45590  0x4f8d     CHENRES08DEL03   30     4.9            13.022394
# 45591  0x5eee    COIMBRES11DEL01   20     4.7            11.001753
# 45592  0x5fb2   RANCHIRES09DEL02   23     4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45588             75.794257          26.912328           75.804257
# 45589              0.000000           0.070000            0.070000
# 45590             80.242439          13.052394           80.272439
# 45591             76.986241          11.041753           77.026241
# 45592             85.325731          23.431058           85.405731
#
#        order_date order_time order_picked_time                weather  \
# 0      19-03-2022   11:30:00          11:45:00       conditions Sunny
# 1      25-03-2022   19:45:00          19:50:00      conditions Stormy
# 2      19-03-2022   08:30:00          08:45:00  conditions Sandstorms
# 3      05-04-2022   18:00:00          18:10:00       conditions Sunny
# 4      26-03-2022   13:30:00          13:45:00      conditions Cloudy
# ...           ...        ...               ...                    ...
# 45588  24-03-2022   11:35:00          11:45:00       conditions Windy
# 45589  16-02-2022   19:55:00          20:10:00       conditions Windy
# 45590  11-03-2022   23:50:00          00:05:00      conditions Cloudy
# 45591  07-03-2022   13:35:00          13:40:00      conditions Cloudy
# 45592  02-03-2022   17:10:00          17:15:00         conditions Fog
#
#        traffic  vehicle_condition type_of_order type_of_vehicle  \
# 0        High                   2        Snack      motorcycle
# 1         Jam                   2        Snack         scooter
# 2         Low                   0       Drinks      motorcycle
# 3      Medium                   0       Buffet      motorcycle
# 4        High                   1        Snack         scooter
# ...        ...                ...           ...             ...
# 45588    High                   1         Meal      motorcycle
# 45589     Jam                   0       Buffet      motorcycle
# 45590     Low                   1       Drinks         scooter
# 45591    High                   0        Snack      motorcycle
# 45592  Medium                   2        Snack         scooter
#
#       multiple_deliveries festival       city_type time_taken
# 0                       0      No           Urban    (min) 24
# 1                       1      No   Metropolitian    (min) 33
# 2                       1      No           Urban    (min) 26
# 3                       1      No   Metropolitian    (min) 21
# 4                       1      No   Metropolitian    (min) 30
# ...                   ...      ...             ...        ...
# 45588                   0      No   Metropolitian    (min) 32
# 45589                   1      No   Metropolitian    (min) 36
# 45590                   0      No   Metropolitian    (min) 16
# 45591                   1      No   Metropolitian    (min) 26
# 45592                   1      No   Metropolitian    (min) 36
#
# [45593 rows x 20 columns]

# %%
data_cleaning(df)
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6             0.000000
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# 1                 77.683237          13.043041           77.813237 2022-03-25
# 2                 77.678400          12.924264           77.688400 2022-03-19
# 3                 76.976494          11.053669           77.026494 2022-04-05
# 4                 80.249982          13.012793           80.289982 2022-03-26
# ...                     ...                ...                 ...        ...
# 45588             75.794257          26.912328           75.804257 2022-03-24
# 45589              0.000000           0.070000            0.070000 2022-02-16
# 45590             80.242439          13.052394           80.272439 2022-03-11
# 45591             76.986241          11.041753           77.026241 2022-03-07
# 45592             85.325731          23.431058           85.405731 2022-03-02
#
#           weather traffic  ...      city_type time_taken city_name  order_day  \
# 0           sunny    high  ...          urban         24      INDO         19
# 1          stormy     jam  ...  metropolitian         33      BANG         25
# 2      sandstorms     low  ...          urban         26      BANG         19
# 3           sunny  medium  ...  metropolitian         21     COIMB          5
# 4          cloudy    high  ...  metropolitian         30      CHEN         26
# ...           ...     ...  ...            ...        ...       ...        ...
# 45588       windy    high  ...  metropolitian         32       JAP         24
# 45589       windy     jam  ...  metropolitian         36       AGR         16
# 45590      cloudy     low  ...  metropolitian         16      CHEN         11
# 45591      cloudy    high  ...  metropolitian         26     COIMB          7
# 45592         fog  medium  ...  metropolitian         36    RANCHI          2
#
#       order_month order_day_of_week  is_weekend pickup_time_minutes  \
# 0               3          saturday           1                15.0
# 1               3            friday           0                 5.0
# 2               3          saturday           1                15.0
# 3               4           tuesday           0                10.0
# 4               3          saturday           1                15.0
# ...           ...               ...         ...                 ...
# 45588           3          thursday           0                10.0
# 45589           2         wednesday           0                15.0
# 45590           3            friday           0                15.0
# 45591           3            monday           0                 5.0
# 45592           3         wednesday           0                 5.0
#
#        order_time_hour  order_time_of_day
# 0                 11.0            morning
# 1                 19.0            evening
# 2                  8.0            morning
# 3                 18.0            evening
# 4                 13.0          afternoon
# ...                ...                ...
# 45588             11.0            morning
# 45589             19.0            evening
# 45590             23.0              night
# 45591             13.0          afternoon
# 45592             17.0            evening
#
# [45502 rows x 25 columns]

# %%
location_subset.columns.tolist()
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude',
#  'restaurant_full_address',
#  'delivery_full_address']

# %%
def calculate_haversine_distance(df):
    location_columns = location_subset.columns.tolist()[:-2]
    lat1 = df[location_columns[0]]
    lon1 = df[location_columns[1]]
    lat2 = df[location_columns[2]]
    lon2 = df[location_columns[3]]

    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(
        dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    distance = 6371 * c

    return (
        df.assign(
            distance = distance)
    )

# %%
# add more data cleaning steps

cleaned_data = (
                df.pipe(data_cleaning)
                .pipe(clean_lat_long)
                .pipe(calculate_haversine_distance)
                )

cleaned_data
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6                  NaN
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# 1                 77.683237          13.043041           77.813237 2022-03-25
# 2                 77.678400          12.924264           77.688400 2022-03-19
# 3                 76.976494          11.053669           77.026494 2022-04-05
# 4                 80.249982          13.012793           80.289982 2022-03-26
# ...                     ...                ...                 ...        ...
# 45588             75.794257          26.912328           75.804257 2022-03-24
# 45589                   NaN                NaN                 NaN 2022-02-16
# 45590             80.242439          13.052394           80.272439 2022-03-11
# 45591             76.986241          11.041753           77.026241 2022-03-07
# 45592             85.325731          23.431058           85.405731 2022-03-02
#
#           weather traffic  ...  time_taken city_name order_day  order_month  \
# 0           sunny    high  ...          24      INDO        19            3
# 1          stormy     jam  ...          33      BANG        25            3
# 2      sandstorms     low  ...          26      BANG        19            3
# 3           sunny  medium  ...          21     COIMB         5            4
# 4          cloudy    high  ...          30      CHEN        26            3
# ...           ...     ...  ...         ...       ...       ...          ...
# 45588       windy    high  ...          32       JAP        24            3
# 45589       windy     jam  ...          36       AGR        16            2
# 45590      cloudy     low  ...          16      CHEN        11            3
# 45591      cloudy    high  ...          26     COIMB         7            3
# 45592         fog  medium  ...          36    RANCHI         2            3
#
#       order_day_of_week is_weekend  pickup_time_minutes order_time_hour  \
# 0              saturday          1                 15.0            11.0
# 1                friday          0                  5.0            19.0
# 2              saturday          1                 15.0             8.0
# 3               tuesday          0                 10.0            18.0
# 4              saturday          1                 15.0            13.0
# ...                 ...        ...                  ...             ...
# 45588          thursday          0                 10.0            11.0
# 45589         wednesday          0                 15.0            19.0
# 45590            friday          0                 15.0            23.0
# 45591            monday          0                  5.0            13.0
# 45592         wednesday          0                  5.0            17.0
#
#        order_time_of_day   distance
# 0                morning   3.025149
# 1                evening  20.183530
# 2                morning   1.552758
# 3                evening   7.790401
# 4              afternoon   6.210138
# ...                  ...        ...
# 45588            morning   1.489846
# 45589            evening        NaN
# 45590              night   4.657195
# 45591          afternoon   6.232393
# 45592            evening  12.074396
#
# [45502 rows x 26 columns]

# %% [markdown]
# ## Validate Data Cleaning

# %%
# age column

cleaned_data['age'].agg(["min","max"])
# Out:
# min    20.0
# max    39.0
# Name: age, dtype: float64

# %%
# ratings column

cleaned_data['ratings'].agg(["min","max"])
# Out:
# min    2.5
# max    5.0
# Name: ratings, dtype: float64

# %%
location_columns=location_subset.columns.tolist()[:-2]

# %%
# location columns

cleaned_data[location_columns].plot(kind="box")

plt.xticks(rotation=45)

display(cleaned_data[location_columns].describe())
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         41872.000000          41872.000000       41872.000000
# mean             18.913696             76.921664          18.977356
# std               5.467265              3.503107           5.469056
# min               9.957144             72.768726           9.967144
# 25%              12.986047             73.897902          13.065996
# 50%              19.065838             76.618203          19.124049
# 75%              22.751234             78.368855          22.820040
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        41872.000000
# mean            76.985325
# std              3.503260
# min             72.778726
# 25%             73.940327
# 50%             76.662620
# 75%             78.405467
# max             88.563452

# %%
# values in categorical columns

cat_cols = cleaned_data.select_dtypes(include="object").columns.tolist()

for col in cat_cols:
    print(f"For {col} unique values are: {cleaned_data[col].unique()}",end="\n\n")
# Out:
# For rider_id unique values are: ['INDORES13DEL02 ' 'BANGRES18DEL02 ' 'BANGRES19DEL01 ' ...
#  'KOCRES04DEL01 ' 'BHPRES06DEL03 ' 'GOARES03DEL03 ']
#
# For weather unique values are: ['sunny' 'stormy' 'sandstorms' 'cloudy' 'fog' 'windy' nan]
#
# For traffic unique values are: ['high' 'jam' 'low' 'medium' nan]
#
# For type_of_order unique values are: ['snack' 'drinks' 'buffet' 'meal']
#
# For type_of_vehicle unique values are: ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
#
# For festival unique values are: ['no' 'yes' nan]
#
# For city_type unique values are: ['urban' 'metropolitian' 'semi-urban' nan]
#
# For city_name unique values are: ['INDO' 'BANG' 'COIMB' 'CHEN' 'HYD' 'RANCHI' 'MYS' 'DEH' 'KOC' 'PUNE'
#  'LUDH' 'KNP' 'MUM' 'KOL' 'JAP' 'SUR' 'GOA' 'AURG' 'AGR' 'VAD' 'ALH' 'BHP']
#
# For order_day_of_week unique values are: ['saturday' 'friday' 'tuesday' 'monday' 'sunday' 'wednesday' 'thursday']
#
# For order_time_of_day unique values are: ['morning' 'evening' 'afternoon' 'night' 'after_midnight']

# %%
# bar plot of missing values

msno.bar(cleaned_data)
# Out:
# <Axes: >

# %%
# matrix of missing values

msno.matrix(cleaned_data)
# Out:
# <Axes: >

# %%
cleaned_data.dtypes
# Out:
# rider_id                        object
# age                            float64
# ratings                        float64
# restaurant_latitude            float64
# restaurant_longitude           float64
# delivery_latitude              float64
# delivery_longitude             float64
# order_date              datetime64[ns]
# weather                         object
# traffic                         object
# vehicle_condition                int64
# type_of_order                   object
# type_of_vehicle                 object
# multiple_deliveries            float64
# festival                        object
# city_type                       object
# time_taken                       int32
# city_name                       object
# order_day                        int32
# order_month                      int32
# order_day_of_week               object
# is_weekend                       int32
# pickup_time_minutes            float64
# order_time_hour                float64
# order_time_of_day               object
# distance                       float64
# dtype: object

# %%
# Filter numeric columns
numeric_data = cleaned_data.select_dtypes(include=['float64', 'int64'])

# Create correlation matrix of missing values
missing_corr = numeric_data.isna().corr()

# Create heatmap using seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(missing_corr, 
            annot=True,
            cmap='RdYlBu',
            vmin=-1,
            vmax=1,
            center=0)
plt.title('Correlation of Missing Values')
plt.tight_layout()
plt.show()

# Print columns analyzed
print("\nColumns included in correlation:")
print(numeric_data.columns.tolist())
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# Columns included in correlation:
# ['age', 'ratings', 'restaurant_latitude', 'restaurant_longitude', 'delivery_latitude', 'delivery_longitude', 'vehicle_condition', 'multiple_deliveries', 'pickup_time_minutes', 'order_time_hour', 'distance']

# %% [markdown]
# # Save Cleaned Data

# %%
df.sample(5)
# Out:
#             id         rider_id age ratings  restaurant_latitude  \
# 28459  0x84bc   BANGRES17DEL03   36       5            12.972532
# 25177   0xcbc   CHENRES17DEL03   32     4.8            13.045479
# 20419   0xe0c    HYDRES07DEL01   33       5            17.424114
# 11553  0x7b63   CHENRES06DEL03   27     4.7            13.054347
# 8268   0xa557    HYDRES09DEL02   25     4.8            17.431668
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 28459             77.608179          13.002532           77.638179
# 25177             80.233110          13.105479           80.293110
# 20419             78.347554          17.464114           78.387554
# 11553             80.257221          13.114347           80.317221
# 8268              78.408321          17.561668           78.538321
#
#        order_date order_time order_picked_time                weather  \
# 28459  07-03-2022   17:30:00          17:45:00         conditions Fog
# 25177  21-03-2022   19:50:00          19:55:00       conditions Windy
# 20419  26-03-2022   14:30:00          14:40:00  conditions Sandstorms
# 11553  05-04-2022   22:50:00          23:00:00       conditions Sunny
# 8268   04-04-2022   17:10:00          17:20:00      conditions Cloudy
#
#        traffic  vehicle_condition type_of_order    type_of_vehicle  \
# 28459  Medium                   2         Meal   electric_scooter
# 25177     Jam                   2       Drinks   electric_scooter
# 20419    High                   1       Buffet            scooter
# 11553     Low                   0       Buffet         motorcycle
# 8268   Medium                   0       Buffet         motorcycle
#
#       multiple_deliveries festival       city_type time_taken
# 28459                   0      No   Metropolitian    (min) 19
# 25177                   1      No   Metropolitian    (min) 26
# 20419                   1      No   Metropolitian    (min) 25
# 11553                   1      No   Metropolitian    (min) 12
# 8268                    1      No   Metropolitian    (min) 30

# %%
cleaned_data.sample(5)
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 40748   COIMBRES02DEL01   30.0      4.6            11.022477
# 40123     HYDRES17DEL01   23.0      4.8            17.451976
# 24734  RANCHIRES04DEL03   23.0      4.2            23.359033
# 42282     KNPRES19DEL03   26.0      4.7            26.490950
# 34679     KOLRES14DEL01   29.0      4.5            22.552996
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 40748             76.995667          11.092477           77.065667 2022-03-18
# 40123             78.385883          17.491976           78.425883 2022-03-13
# 24734             85.325347          23.389033           85.355347 2022-03-19
# 42282             80.318656          26.580950           80.408656 2022-02-14
# 34679             88.352310          22.662996           88.462310 2022-02-18
#
#           weather traffic  ...  time_taken city_name order_day  order_month  \
# 40748       sunny     low  ...          29     COIMB        18            3
# 40123  sandstorms  medium  ...          25       HYD        13            3
# 24734      cloudy     jam  ...          31    RANCHI        19            3
# 42282       windy     jam  ...          24       KNP        14            2
# 34679  sandstorms     jam  ...          24       KOL        18            2
#
#       order_day_of_week is_weekend  pickup_time_minutes order_time_hour  \
# 40748            friday          0                 15.0            22.0
# 40123            sunday          1                 15.0            15.0
# 24734          saturday          1                  5.0            20.0
# 42282            monday          0                 15.0            21.0
# 34679            friday          0                 10.0            19.0
#
#        order_time_of_day   distance
# 40748              night  10.906037
# 40123          afternoon   6.146747
# 24734              night   4.528165
# 42282              night  13.428042
# 34679            evening  16.646528
#
# [5 rows x 26 columns]

# %%
# save the cleaned data

cleaned_data.to_csv("cleaned_data.csv",index=False)
